# %% [markdown]
# # Digital Shift: The Evolution of Products and Platforms in Portuguese E-commerce

# %% [markdown]
# ### Data Processor:

# %%
sites = ["www.fnac.pt", "www.worten.pt", "www.elcorteingles.pt", "www.radiopopular.pt", "www.staples.pt", "www.pcdiga.com"]

# %%
import requests
import urllib.parse
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
#  ## Extracting product categories from the websites (2007 | 2010 | 2015 | 2020 | 2023)
#
# We will use the BeautifulSoup library to extract the product categories from the websites, and we will use the requests library to get the HTML content of the websites.
# We had to create a different script for each year and site, because the structure of the sites is different for each year and site.

# %%
df = pd.read_csv("data/sites_links.csv")
df.head()
# Out:
#    Unnamed: 0                                        www.fnac.pt  \
# 0        2005                                                NaN
# 1        2006  https://arquivo.pt/wayback/20061118120805/http...
# 2        2007  https://arquivo.pt/wayback/20070928223117/http...
# 3        2008  https://arquivo.pt/wayback/20081027081756/http...
# 4        2009  https://arquivo.pt/wayback/20091218064527/http...
#
#                                        www.worten.pt  \
# 0                                                NaN
# 1                                                NaN
# 2  https://arquivo.pt/wayback/20070611190104/http...
# 3  https://arquivo.pt/wayback/20081022044251/http...
# 4  https://arquivo.pt/wayback/20091218174523/http...
#
#                                 www.elcorteingles.pt  \
# 0  https://arquivo.pt/wayback/20050725031922/http...
# 1  https://arquivo.pt/wayback/20060216170739/http...
# 2  https://arquivo.pt/wayback/20070929080902/http...
# 3  https://arquivo.pt/wayback/20081021184312/http...
# 4  https://arquivo.pt/wayback/20091218054927/http...
#
#                                  www.radiopopular.pt  \
# 0  https://arquivo.pt/wayback/20050722223614/http...
# 1                                                NaN
# 2  https://arquivo.pt/wayback/20070929122436/http...
# 3  https://arquivo.pt/wayback/20081022013802/http...
# 4  https://arquivo.pt/wayback/20091218134419/http...
#
#                                       www.staples.pt  \
# 0  https://arquivo.pt/wayback/20050722174753/http...
# 1                                                NaN
# 2  https://arquivo.pt/wayback/20070610185333/http...
# 3  https://arquivo.pt/wayback/20081022031557/http...
# 4  https://arquivo.pt/wayback/20091218154357/http...
#
#                                       www.pcdiga.com
# 0  https://arquivo.pt/wayback/20050719124815/http...
# 1                                                NaN
# 2                                                NaN
# 3  https://arquivo.pt/wayback/20081022130111/http...
# 4  https://arquivo.pt/wayback/20091219171727/http...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            19 non-null     int64
#  1   www.fnac.pt           16 non-null     object
#  2   www.worten.pt         14 non-null     object
#  3   www.elcorteingles.pt  16 non-null     object
#  4   www.radiopopular.pt   17 non-null     object
#  5   www.staples.pt        18 non-null     object
#  6   www.pcdiga.com        16 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
print(df.isna().sum())
df.isna()
# Out:
# Unnamed: 0              0
# www.fnac.pt             3
# www.worten.pt           5
# www.elcorteingles.pt    3
# www.radiopopular.pt     2
# www.staples.pt          1
# www.pcdiga.com          3
# dtype: int64
#     Unnamed: 0  www.fnac.pt  www.worten.pt  www.elcorteingles.pt  \
# 0        False         True           True                 False
# 1        False        False           True                 False
# 2        False        False          False                 False
# 3        False        False          False                 False
# 4        False        False          False                 False
# 5        False        False          False                 False
# 6        False        False          False                 False
# 7        False        False          False                 False
# 8        False        False          False                 False
# 9        False        False          False                 False
# 10       False        False          False                 False
# 11       False        False          False                 False
# 12       False         True           True                 False
# 13       False        False          False                  True
# 14       False         True           True                  True
# 15       False        False          False                 False
# 16       False        False           True                  True
# 17       False        False          False                 False
# 18       False        False          False                 False
#
#     www.radiopopular.pt  www.staples.pt  www.pcdiga.com
# 0                 False           False           False
# 1                  True            True            True
# 2                 False           False            True
# 3                 False           False           False
# 4                 False           False           False
# 5                 False           False           False
# 6                 False           False           False
# 7                 False           False            True
# 8                 False           False           False
# 9                 False           False           False
# 10                False           False           False
# 11                False           False           False
# 12                False           False           False
# 13                False           False           False
# 14                False           False           False
# 15                False           False           False
# 16                 True           False           False
# 17                False           False           False
# 18                False           False           False

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'www.fnac.pt', 'www.worten.pt', 'www.elcorteingles.pt',
#        'www.radiopopular.pt', 'www.staples.pt', 'www.pcdiga.com'],
#       dtype='object')

# %%
header = ['ano', 'link', 'site', 'numero_categorias', 'lista_categorias', 'dicionario_subcategorias']
header_df = pd.DataFrame(columns=header)
header_df.to_csv("data/ecommerce_category_analysis_all.csv", index=False)

# %% [markdown]
# WORTEN

# %%
def extractor_2007_worten(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')

        categories_container = soup.find('ul', class_='menu')

        categories_dict = {}

        for category in categories_container.find_all('li'):
            main_category_name = category.find('a').get_text(strip=True)
            
        # nao tem subcategorias
            categories_dict[main_category_name] = []

        return len(categories_dict), categories_dict
    except Exception as e:
        return 0, {}
    
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.worten.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year <= 2012:
                link = link + 'Splash.aspx'
            if year == 2007:
                num_categories, category_dict = extractor_2007_worten(link)

                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2010_worten(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')

            categories_container = soup.find('ul', class_='menu menu-category')

            categories_dict = {}

            for category in categories_container.find_all('li', class_='sub'):
                main_category_name = category.find('a', class_='label').get_text(strip=True)
                subcategories = []

                subcategories_container = category.find('ul')
                if subcategories_container:
                    for subcategory in subcategories_container.find_all('li'):
                        # Extract subcategory name
                        subcategory_name = subcategory.find('a', class_='label').get_text(strip=True)
                        subcategories.append(subcategory_name)

                categories_dict[main_category_name] = subcategories

            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.worten.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            link = link + 'default.aspx'    
            if year == 2010:
                num_categories, category_dict = get_categories_2010_worten(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2015_worten(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')

            categories_container = soup.find('ul', id='nav')

            categories_dict = {}

            for category in categories_container.find_all('li', class_='level1'):
                main_category_name = category.find('a').find('span').get_text(strip=True)
                subcategories = []

                subcategories_container = category.find('ul')
                if subcategories_container:
                    for subcategory in subcategories_container.find_all('li', class_='level2'):
                        # Extract subcategory name
                        subcategory_name = subcategory.find('span').get_text(strip=True)
                        subcategories.append(subcategory_name)
                categories_dict[main_category_name] = subcategories

            # se houver subcategorias com [] é porque não tem subcategorias, e eliminar categoria
            for key in list(categories_dict.keys()):
                if len(categories_dict[key]) == 0:
                    del categories_dict[key]
                    
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.worten.pt' and (year not in category_analysis['ano'].values or site_column not in category_analysis['site'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2015:
                num_categories, category_dict = get_categories_2015_worten(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_worten_2020_23(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')

            categories_container = soup.find('ul', class_='nav-sub js-nav-sub')

            categories_dict = {}

            for category in categories_container.find_all('li', class_='nav-item nav-item-sub'):
                
                main_category_name = category.find('span', class_='nav-a').get_text(strip=True)
                subcategories = []

                subcategories_container = category.find('ul', class_='nav nav-sub nav-sub-child js-nav-sub')
                for sub in subcategories_container.find_all('li', class_='nav-item-sub'):
                    label = sub.find('label', class_='nav-trigger js-nav-trigger')
                    if label:
                        subcategory_name = label.find('a', class_='nav-a')
                        if subcategory_name:
                            subcategories.append(subcategory_name.get_text(strip=True).lower())

                categories_dict[main_category_name] = subcategories

            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}

        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.worten.pt' and (year not in category_analysis['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2020 or year == 2023:
                num_categories, category_dict = get_categories_worten_2020_23(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %% [markdown]
# Staples Extracted Categories:

# %%
def get_categories_staples_2007_10(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')
        # span com id que contem a palavra categorias
        categories_container = soup.find('span', id= lambda x: x and 'categorias' in x.lower())

        categories_dict = {}

        current_main_category = None
        for div in categories_container.find_all('div', class_='tracos_centro'):
            a_tag = div.find('a')
            if not a_tag:
                continue

            category_name = a_tag.get_text(strip=True)

            if 'tit_centro_blue_bold' in a_tag.get('class', []):
                # Main category
                current_main_category = category_name
                categories_dict[current_main_category] = []
            else:
                # Subcategory
                if current_main_category:
                    categories_dict[current_main_category].append(
                         category_name
                    )

        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}


category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.staples.pt' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            link += 'default.aspx'
            if year == 2007 or year == 2010:
                num_categories, category_dict = get_categories_staples_2007_10(link)

                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_staples_15(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')
        # span com id que contem a palavra categorias
        categories_container = soup.find('div', class_='primaryNav')

        categories_dict = {}

        current_main_category = None
        for div in categories_container.find_all('span', class_='navItem'):
            current_main_category = div.find('a', class_='navLink').get_text(strip=True)
            categories_dict[current_main_category] = []

        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.staples.pt' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year == 2015:
                num_categories, category_dict = get_categories_staples_15(link)

                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_staples_20(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')
        # span com id que contem a palavra categorias
        categories_container = soup.find('div', class_='primaryNav')
        categories_dict = {}

        current_main_category = None
        for div in categories_container.find_all('span', class_='navItem'):
            current_main_category = div.find('a', class_='navLink').get_text(strip=True)
            categories_dict[current_main_category] = []


        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.staples.pt' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year == 2020:
                num_categories, category_dict = get_categories_staples_20(link)

                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_staples_23(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')
        # span com id que contem a palavra categorias
        categories_container = soup.find('div', class_='container-menu-children')
        print(categories_container)
        categories_dict = {}

        current_main_category = None
        for div in categories_container.find_all('div', class_='children-cont'):
            main_category_tag = div.find('span', class_='pr-name')
            if main_category_tag:
                current_main_category = main_category_tag.get_text(strip=True)
                categories_dict[current_main_category] = []
            else:
                if current_main_category:
                    subcategory_link = div.find('a', class_='menu-link_a')
                    if subcategory_link:
                        subcategory_name = subcategory_link.get_text(strip=True)
                        categories_dict[current_main_category].append(subcategory_name)


        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.staples.pt' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year == 2023:
                num_categories, category_dict = get_categories_staples_23(link)

                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %% [markdown]
# PcDiga Extracted Categories:
# - As it is not possible to extract categories from 2007, we will extract from 2008, assuming that the differences between 2007 and 2008 are minimal.
# - As it is not possible to extract categories from 2023, we assume that the differences between 2020 and 2023 are minimal, or probably the same.

# %%
def get_categories_pcdiga_08(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')

        categories_container = soup.find('map', attrs={'name': 'Map'})

        categories_dict = {}

        for category in categories_container.find_all('area'):
            # extrair o nome do href = ...?Familia=nome
            category_href = category
            main_category_name = category.get('href').split('=')[-1]

            subcategories = []

            # a categoria principal não tem subcategorias
            categories_dict[main_category_name] = subcategories


        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.pcdiga.com' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            link += 'pcdiga/'
            if year == 2008 or year == 2010:
                n_year = year - 1 if year == 2008 else year
                num_categories, category_dict = get_categories_pcdiga_08(link)

                category_data.append({
                    'ano': n_year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })

        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_pcdiga_15(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')

        categories_container = soup.find('div', id='masterdiv')

        categories_dict = {}

        for category in categories_container.find_all('table', class_='menu1'):
            main_category_name = category.find('a', class_='menu').get_text(strip=True)
            subcategories = []
            categories_dict[main_category_name] = subcategories


        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.pcdiga.com' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year == 2015:

                num_categories, category_dict = get_categories_pcdiga_15(link)
                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })

        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_pcdiga_20(url):
    try:
        request = requests.get(url)
        request.raise_for_status()

        soup = BeautifulSoup(request.text, 'html.parser')

        categories = soup.find('div', class_='megamenu-wrapper')
        categories_container = categories.find('ul', class_='megamenu')
        categories_dict = {}

        for category in categories_container.find_all('li'):
            main_category_link = category.find('a', class_='i-link')
            svg_element = category.find('span', class_='svg-i svg-arrow')
            if not main_category_link or not svg_element:
                continue  

            main_category_name = main_category_link.find('span', class_='lnk-text').get_text(strip=True)

            subcategories = []
            subcategories_container = category.find('div', class_='submenu')
            if subcategories_container:
                for subcategory in subcategories_container.find_all('li'):
                    subcategory_link = subcategory.find('a', class_='i-link')
                    if subcategory_link:
                        subcategory_name = subcategory_link.find('span').get_text(strip=True)
                        subcategories.append(subcategory_name)  

            categories_dict[main_category_name] = subcategories

        return len(categories_dict), categories_dict
    except Exception as e:
        print(f"Error while extracting categories: {e}")
        return 0, {}

category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.pcdiga.com' and (year not in category_analysis[category_analysis['site'] == site_column]['ano'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/') 
            if year == 2020:
                num_categories, category_dict = get_categories_pcdiga_20(link)
                category_data.append({
                    'ano': year,
                    'link': link,
                    'site': site_column,
                    'numero_categorias': num_categories,
                    'lista_categorias': list(category_dict.keys()),
                    'dicionario_subcategorias': category_dict
                })

        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %% [markdown]
# RadioPopular Extracted Categories:

# %%
def get_categories_2010_rp(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            categories_dict = {}

            for category in soup.find_all('td', align='left'):
                a = category.find('a')
                if a:
                    main_category_name = a.find('img').get('alt')
                    categories_dict[main_category_name] = []
            for i in list(categories_dict.keys()):
                if i == 'Recrutamento':
                    del categories_dict[i]
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.radiopopular.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2010 or year == 2007:
                num_categories, category_dict = get_categories_2010_rp(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2015_rp(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            categories_dict = {}

            # Encontrar o div com as categorias principais
            div = soup.find('div', id='nav')
            if div is None:
                return 0, {} 

            for category in div.find_all('li', class_='dir'):
                main_category_name = category.find('a').get_text(strip=True)
                subcategories = []

                subcategories_container = category.find('ul')
                if subcategories_container:
                    for subcategory in subcategories_container.find_all('li', class_='dir'):
                        subcategory_name = subcategory.find('a').get_text(strip=True)
                        subcategories.append(subcategory_name)

                if subcategories:
                    categories_dict[main_category_name] = subcategories
                else:
                    categories_dict[main_category_name] = []

            # vamos ver todas as keys que tem [] e eliminar, pois não tem subcategorias
            for key in list(categories_dict.keys()):
                if len(categories_dict[key]) == 0:
                    del categories_dict[key]
                    
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.radiopopular.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2015:
                num_categories, category_dict = get_categories_2015_rp(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2020_rp(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            categories_dict = {}

            # Encontrar o div com as categorias principais
            ul = soup.find('ul', class_='categories')

            for i in ul.find_all('li', class_='category link cb'):
                main_category_name = i.find('a').get_text(strip=True)
                subcategories = []
                div = i.find('div', class_='subcategories')
                if div:
                    for subcategory in div.find_all('li', class_="subcategory family link"):
                        subcategory_name = subcategory.get_text(strip=True)
                        subcategories.append(subcategory_name)
                categories_dict[main_category_name] = subcategories
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.radiopopular.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')    
            if year == 2020 or year == 2023:
                num_categories, category_dict = get_categories_2020_rp(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %% [markdown]
# As elcorreioingles does not have product categories, we will not use this site to make this comparison

# %% [markdown]
# Fnac Extracted Categories:

# %% [markdown]
# As is not possible to extract categories, from 2006 and 2008, we will not use the year 2007 in fnac to make the comparison
#
# Error message presented:```O seu browser não aceita cookies, pelo que não é possível o acesso ao nosso site.```

# %%
def get_categories_2010_fnac(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            div = soup.find('div', id='menu')
            u = div.find('ul', style="margin-left: 40px")
            categories_dict = {}
            main_category_name = None
            for category in u.find_all('li'):
                a = category.find('a')
                if a:
                    main_category_name = a.get_text(strip=True)
                subcategories = []
                ul = category.find('ul')
                if ul:
                    for subcategory in ul.find_all('li'):
                        subcategory_name = subcategory.find('a').get_text(strip=True)
                        subcategory_name = subcategory_name.replace('»', '').replace('\r\n', '').strip()
                        subcategory_name = ' '.join(subcategory_name.split())
                        subcategories.append(subcategory_name)
                    if subcategories:
                        categories_dict[main_category_name] = subcategories
                    else:
                        categories_dict[main_category_name] = []

            for key in list(categories_dict.keys()):
                if len(categories_dict[key]) == 0:
                    del categories_dict[key]
            for value in categories_dict.values():
                if 'Ver todos os produtos' in value:
                    value.remove('Ver todos os produtos')

            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.fnac.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2010:
                num_categories, category_dict = get_categories_2010_fnac(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2015_fnac(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            div = soup.find('div', id='MENU')
            u = div.find('ul', id="onglets")
            categories_dict = {}
            main_category_name = None
            for category in u.find_all('li'):
                a = category.find('a')
                if a:
                    span = a.find('span', class_='inner')
                    main_category_name = a.get_text(strip=True)
                subcategories = []
                
                div = category.find('div', class_='megaMenu')
                if div:
                    for sub in div.find_all('dt'):
                        # pode ja ter subcategoria ou ter um <a> com a subcategoria
                        subcategory_name = sub.get_text(strip=True)
                        if subcategory_name:
                            subcategories.append(subcategory_name)

                    if subcategories:
                        categories_dict[main_category_name] = subcategories
                    else:
                        categories_dict[main_category_name] = []

            for key in list(categories_dict.keys()):
                if len(categories_dict[key]) == 0:
                    del categories_dict[key]

            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.fnac.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2015:
                num_categories, category_dict = get_categories_2015_fnac(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2020_fnac(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            div = soup.find('div', class_='Sidebar-nano nano')
            categories_dict = {}
            main_category_name = None

            ul = div.find('ul', class_="CategoryNav js-CategoryNav")
            for il in ul.find_all('li', class_='CategoryNav-item js-CategoryNav-item'):
                main_category_name = il.find('a').get_text(strip=True)
                subcategories = []  
                categories_dict[main_category_name] = subcategories
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.fnac.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2020:
                num_categories, category_dict = get_categories_2020_fnac(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %%
def get_categories_2023_fnac(url):
        try:
            request = requests.get(url)
            request.raise_for_status()

            soup = BeautifulSoup(request.text, 'html.parser')
            div = soup.find('div', class_='SideNavPanel-listWrapper')
            categories_dict = {}
            main_category_name = None

            ul = div.find('ul', class_="SideNavPanel-list")
            for il in ul.find_all('li', class_='SideNavPanel-listItem js-SideNavPanel-listItem'):
                main_category_name = il.find('a').get_text(strip=True)
                subcategories = []  
                categories_dict[main_category_name] = subcategories
            return len(categories_dict), categories_dict
        except Exception as e:
            return 0, {}
        
category_data = []

data = pd.read_csv('data/sites_links.csv')
category_analysis = pd.read_csv('data/ecommerce_category_analysis_all.csv')

for index, row in data.iterrows():
    year = row['Unnamed: 0']
    
    for site_column in data.columns[1:]:
        link = row[site_column]
        if pd.notna(link) and site_column == 'www.fnac.pt' and (link not in category_analysis['link'].values):
            link = link.replace(f'/http://{site_column}/', f'mp_/http://{site_column}/')      
            if year == 2023:

                num_categories, category_dict = get_categories_2023_fnac(link)
                if num_categories > 0:
                    category_data.append({
                        'ano': year,
                        'link': link,
                        'site': site_column,
                        'numero_categorias': num_categories,
                        'lista_categorias': list(category_dict.keys()),
                        'dicionario_subcategorias': category_dict
                    })
        else:
            continue

# Adicionar os dados coletados ao csv
category_data_df = pd.DataFrame(category_data)
category_data_df.to_csv("data/ecommerce_category_analysis_all.csv", mode='a', header=False, index=False)

# %% [markdown]
#  ## Extracting product prices
#
# We will use the BeautifulSoup library to extract the product prices from the websites, and we will use the requests library to get the HTML content of the websites.

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')

# %%
df.head()
# Out:
#           site       model    periodo  \
# 0  www.fnac.pt   huawei p8  2016-2020
# 1  www.fnac.pt   huawei p8  2016-2020
# 2  www.fnac.pt  huawei p20  2016-2020
# 3  www.fnac.pt  huawei p20  2016-2020
# 4  www.fnac.pt  huawei p30  2016-2020
#
#                                                title  \
# 0       Huawei P8 Lite Huawei - Tecnologia - Fnac.pt
# 1  HUAWEI TELEMOVEL HUAWEI P8 DS 64GB, SmartPhone...
# 2  Smartphone Huawei P20 - 128GB - Black - SmartP...
# 3  Smartphone Huawei P20 Pro - 128GB - Black - Sm...
# 4            Novos Huawei P30 - Sabe mais em Fnac.pt
#
#                                          originalURL  \
# 0  https://www.fnac.pt/Smartphones-e-Telemoveis/S...
# 1  http://www.fnac.pt/HUAWEI-TELEMOVEL-HUAWEI-P8-...
# 2  https://www.fnac.pt/Smartphone-Huawei-P20-128G...
# 3  https://www.fnac.pt/Smartphone-Huawei-P20-Pro-...
# 4                   https://www.fnac.pt/novos-huawei
#
#                                        linkToArchive          tstamp  \
# 0  https://arquivo.pt/wayback/20170819112525/http...  20170819112525
# 1  https://arquivo.pt/wayback/20160211013245/http...  20160211013245
# 2  https://arquivo.pt/wayback/20190422222720/http...  20190422222720
# 3  https://arquivo.pt/wayback/20190422222711/http...  20190422222711
# 4  https://arquivo.pt/wayback/20190323202914/http...  20190323202914
#
#    contentLength                            digest   mimeType  ...  \
# 0         188977  d129cd257066d54e046fd147e20e50a0  text/html  ...
# 1         168566  e7cba63ab0ad2ff865ee01fc24aaeb21  text/html  ...
# 2         311043  85b8ba9669ccbedeae1fcd8fe1d10abd  text/html  ...
# 3         293053  2530c422432b25e633797fa5469eb6b5  text/html  ...
# 4          57729  38aaee64d7aa7b777d18759f0de09b53  text/html  ...
#
#          date                                   linkToScreenshot  \
# 0  1503141925  https://arquivo.pt/screenshot?url=https%3A%2F%...
# 1  1455154365  https://arquivo.pt/screenshot?url=https%3A%2F%...
# 2  1555972040  https://arquivo.pt/screenshot?url=https%3A%2F%...
# 3  1555972031  https://arquivo.pt/screenshot?url=https%3A%2F%...
# 4  1553372954  https://arquivo.pt/screenshot?url=https%3A%2F%...
#
#                                        linkToNoFrame  \
# 0  https://arquivo.pt/noFrame/replay/201708191125...
# 1  https://arquivo.pt/noFrame/replay/201602110132...
# 2  https://arquivo.pt/noFrame/replay/201904222227...
# 3  https://arquivo.pt/noFrame/replay/201904222227...
# 4  https://arquivo.pt/noFrame/replay/201903232029...
#
#                                  linkToExtractedText  \
# 0  https://arquivo.pt/textextracted?m=https%3A%2F...
# 1  https://arquivo.pt/textextracted?m=http%3A%2F%...
# 2  https://arquivo.pt/textextracted?m=https%3A%2F...
# 3  https://arquivo.pt/textextracted?m=https%3A%2F...
# 4  https://arquivo.pt/textextracted?m=https%3A%2F...
#
#                                       linkToMetadata  \
# 0  https://arquivo.pt/textsearch?metadata=https%3...
# 1  https://arquivo.pt/textsearch?metadata=http%3A...
# 2  https://arquivo.pt/textsearch?metadata=https%3...
# 3  https://arquivo.pt/textsearch?metadata=https%3...
# 4  https://arquivo.pt/textsearch?metadata=https%3...
#
#                                   linkToOriginalFile  \
# 0  https://arquivo.pt/noFrame/replay/201708191125...
# 1  https://arquivo.pt/noFrame/replay/201602110132...
# 2  https://arquivo.pt/noFrame/replay/201904222227...
# 3  https://arquivo.pt/noFrame/replay/201904222227...
# 4  https://arquivo.pt/noFrame/replay/201903232029...
#
#                                              snippet  \
# 0  <em>Huawei</em> <em>P8</em> Lite <em>Huawei</e...
# 1  <em>HUAWEI</em> TELEMOVEL <em>HUAWEI</em> <em>...
# 2  Smartphone <em>Huawei</em> <em>P20</em> - 128G...
# 3  Smartphone <em>Huawei</em> <em>P20</em> Pro - ...
# 4  Novos <em>Huawei</em> <em>P30</em> - Sabe mais...
#
#                                   fileName collection    offset
# 0  IAH-20170819112306-68006-p81.arquivo.pt      AWP24   3773684
# 1  IAH-20160211012526-43988-p81.arquivo.pt      AWP20  44697354
# 2     WEB-20190422222653112-p81.arquivo.pt      AWP29  63201824
# 3     WEB-20190422222653112-p81.arquivo.pt      AWP29  19579119
# 4     WEB-20190323202843497-p81.arquivo.pt      AWP29  87173605
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   site                 176 non-null    object
#  1   model                176 non-null    object
#  2   periodo              176 non-null    object
#  3   title                176 non-null    object
#  4   originalURL          176 non-null    object
#  5   linkToArchive        176 non-null    object
#  6   tstamp               176 non-null    int64
#  7   contentLength        176 non-null    int64
#  8   digest               176 non-null    object
#  9   mimeType             176 non-null    object
#  10  encoding             176 non-null    object
#  11  date                 176 non-null    int64
#  12  linkToScreenshot     176 non-null    object
#  13  linkToNoFrame        176 non-null    object
#  14  linkToExtractedText  176 non-null    object
#  15  linkToMetadata       176 non-null    object
#  16  linkToOriginalFile   176 non-null    object
#  17  snippet              176 non-null    object
#  18  fileName             176 non-null    object
#  19  collection           176 non-null    object
#  20  offset               176 non-null    int64
# dtypes: int64(4), object(17)
# memory usage: 29.0+ KB

# %% [markdown]
# <br>
#
# Initially, we attempted to extract product prices from all pages using links to the extracted text, but due to a lack of consistent patterns, this approach was unsuccessful. In some cases, there were multiple products on a single page, while others contained only one. To maximize extraction, we created a web scraping script tailored to each page type. The script efficiently handles various page layouts, extracting prices for all products on multi-product pages and retrieving the price of the sole product on single-product pages.
#
# <br>

# %% [markdown]
# # Fnac Product Prices

# %%
def extract_prices(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    price_container = soup.find("div", id="ArticleHeaderPT_FullPricerControl_ctl00_BuyBoxMarketPlace_OfferPrice1")
    if price_container:
        price_single = price_container.find("span", class_="price")
        if price_single:
            price = price_single.get_text(strip=True)
            print('1.', price)
            return {'current_price': price}
        
    price_container_box = soup.find("div", class_="ProductPriceBox")
    if price_container_box:
        price_single = price_container_box.find("strong", class_="product-price")
        if price_single:
            price = price_single.get_text(strip=True)
            print('1.', price)
            return {'current_price': price}

    price_box = soup.find("div", class_="f-priceBox")
    if price_box:
        old_price = price_box.find("span", class_="f-priceBox-price f-priceBox-price--old")
        current_price = price_box.find("span", class_="f-priceBox-price f-priceBox-price--reco checked")
        if old_price and current_price:
            print('2.',old_price.get_text(strip=True), current_price.get_text(strip=True))
            return {'old_price': old_price.get_text(strip=True), 'current_price': current_price.get_text(strip=True)}
        else:
            print('3.',current_price.get_text(strip=True))
            return {'current_price': current_price.get_text(strip=True)}
    
    product_list = soup.find_all("li", class_="clearfix Article-item") or soup.find_all("div", class_="Article-itemGroup")
    if product_list:
        products = []
        for product in product_list:
            name_tag = product.find("a", class_="js-minifa-title") or product.find("p", class_="Article-desc")
            product_name = name_tag.get_text(strip=True) if name_tag else None

            old_price_tag = product.find("span", class_="oldPrice")
            current_price_tag = product.find("a", class_="userPrice") or product.find("strong", class_="userPrice")
            if old_price_tag and current_price_tag:
                old_price = old_price_tag.get_text(strip=True)
                current_price = current_price_tag.get_text(strip=True)
                print('4.',product_name, old_price, current_price)
                products.append({
                'product_name': product_name,
                'old_price': old_price,
                'current_price': current_price
                })
            elif current_price_tag and not old_price_tag:
                old_price = None
                current_price = current_price_tag.get_text(strip=True)
                print('5.',product_name, current_price)
                products.append({
                    'product_name': product_name,
                    'current_price': current_price
                })
        
        return products if products else None

    blk_inside = soup.find("div", class_="blk_inside")
    if blk_inside:
        products = []
        for produit in blk_inside.find_all("div", class_="produit"):
            name_tag = produit.find("dt")
            product_name = name_tag.get_text(strip=True) if name_tag else None
            
            price_tag = produit.find("span", class_="smallPrice")
            price = price_tag.get_text(strip=True) if price_tag else None
            print('6.',product_name, price)
            products.append({
                'product_name': product_name,
                'current_price': price
            })
        
        return products if products else None

    product_list = soup.find_all("div", class_="thumbnail")
    if product_list:
        products = []
        for product in product_list:
            name_tag = product.find("a", class_="thumbnail-titleLink")
            product_name = name_tag.get_text(strip=True) if name_tag else None
            
            price_tag = product.find("span", class_="thumbnail-price")
            old_price_tag = product.find("del", class_="thumbnail-priceOld")
            
            current_price = price_tag.get_text(strip=True) if price_tag else None
            old_price = old_price_tag.get_text(strip=True) if old_price_tag else None

            if current_price and old_price:
                print('7.',product_name, old_price, current_price)
                products.append({
                    'product_name': product_name,
                    'old_price': old_price,
                    'current_price': current_price
                })
            elif current_price and not old_price:
                print('8.',product_name, current_price)
                products.append({
                    'product_name': product_name,
                    'current_price': current_price
                })
        return products if products else None

    return None

# %%
def process_row_FNAC(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.fnac.pt':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
            
            extracted_data = extract_prices(text, site)
            
            if extracted_data:
                if isinstance(extracted_data, list):
                    for product in extracted_data:
                        old = product['old_price'] if 'old_price' in product else None
                        current = product['current_price'] if 'current_price' in product else None
                        price = [current, old] if old and current else [current]
                        titulo = product['product_name'] if 'product_name' in product else None
                        extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': titulo,
                            'extractedData': price,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
                else:
                    old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                    current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                    price = [current, old] if old and current else [current]
                    
                    extracted_data_list.append({
                        'site': site,
                        'date': date,
                        'title': title,
                        'extractedData': price,
                        'linkToArchive': link,
                        'linkToExtractedText': row['linkToExtractedText'],
                        'snippet': snippet
                    })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')        
result_list = process_row_FNAC(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']

df_result.to_csv('data/products_extracted_prices_FNAC.csv', index=False)
# Out:
# 4. Huawei P8 Lite 2017 - Black 259,99 € 219,99 €
# 4. Huawei P8 Lite (Black) 229,99 € 179,99 €
# 4. Huawei P8 Lite (Gold) 229,99 € 179,99 €
# 4. Huawei P8 Lite 2017 - Gold 259,99 € 219,99 €
# 4. Huawei P8 Lite (White) 229,99 € 179,99 €
# 4. Huawei P8 Lite 2017 - White 259,99 € 219,99 €
# 5. Huawei P8 Lite 16GB 4G Preto 169,90 €
# 5. Smartphone Huawei P8 Lite Dual Sim 2GB 16GB Dourado 179,30 €
# 5. Huawei P8 Lite 16GB 4G Branco 169,93 €
# 5. Huawei P8 Lite 2017 Dual SIM 4G 16GB Azul 286,68 €
# 5. smartphone Huawei P8 Lite 772997 4G 16GB Preto 283 €
# 5. Huawei P8 Lite 2017 4G 16GB Dourado 278 €
# 5. Huawei P8 Lite 2017 4G 16GB 278 €
# 5. Huawei P8 Lite 2017 4G 16GB 278 €
# 5. Smartphone HUAWEI P8 Lite 4G 16GB (Preto) 172,90 €
# 5. Huawei P8 Lite 4G 16GB Branco 169,90 €
# 5. Huawei P8 Lite 16GB 4G Preto 169,90 €
# 3. 599,99 €
# 3. 799,99 €
# 2. 379,99 € 349,99 €
# 3. 1 049,99 €
# 3. 1 049,99 €
# 4. Samsung Galaxy S8 - G950FZ - Preto Meia-Noite 719,99 € 549,99 €
# 4. Samsung Galaxy S8+ - G955FZ - Prateado 819,99 € 649,99 €
# 4. Samsung Galaxy S8 - G950FZ - Prateado 719,99 € 549,99 €
# 4. Samsung Galaxy S8 - G950FZ - Cinzento Orquídea 719,99 € 549,99 €
# 5. Samsung Galaxy S8+ - G955FZ - Preto Meia-Noite 469,90 €
# 5. Samsung Galaxy S8 Dual Sim- G950F-DS - Preto Meia-Noite 442,28 €
# 5. Samsung Galaxy S8+ - G955FD - Preto Meia-Noite 458,80 €
# 5. Samsung Galaxy S8+ Dual Sim - G955F/DS - Maple Dourado 458 €
# 5. Samsung Galaxy S8 - G950FZ - Rosa 546 €
# 5. Samsung Galaxy S8+ - G955FZ - Cinzento Orquídea 471,10 €
# 5. Smartphone Samsung Galaxy S8+ G955Fds Dual SIM 4GB 64GB Cinzento Orquídea 478 €
# 5. Samsung Galaxy S8 PLUS SM-G955F 4GB RAM 64 GB Preto 475,99 €
# 5. Smartphone Samsung Galaxy S8 - 64GB - Blue Coral 516,89 €
# 5. Smartphone Samsung Galaxy S8 G950F - 64GB - Preto Meia-Noite 533,49 €
# 5. Smartphone Samsung Galaxy S8 G950F - 64GB - Coral Blue 438,10 €
# 5. Smartphone Samsung Galaxy S8 Plus Dual SIM 6GB 128GB Cinzento Orquídea 719,99 €
# 5. Smartphone Samsung Galaxy S8 G950Fds Dual SIM 4GB 64GB Coral Azul 458,89 €
# 5. Smartphone Samsung Galaxy S8 G950Fds Dual SIM 4GB 64GB Cinzento Orquídea 444,80 €
# 5. Smartphone TIM Samsung Galaxy S8 4GB 64 GB Azul 583 €
# 5. Smartphone Telekom Samsung Galaxy S8 Plus 4GB 64 GB Cinzento 475,99 €
# 4. Samsung Galaxy S8+ - G955FZ - Prateado 819,99 € 679,99 €
# 4. Samsung Galaxy S8+ - G955FZ - Preto Meia-Noite 819,99 € 679,99 €
# 4. Samsung Galaxy S8 - G950FZ - Rosa 719,99 € 589,99 €
# 5. Samsung Galaxy S8+ - G955FD - Preto Meia-Noite 819,99 €
# 4. Samsung Galaxy S8 - G950FZ - Cinzento Orquídea 719,99 € 589,99 €
# 5. Samsung Galaxy S8+ Dual Sim - G955F/DS - Maple Dourado 819,99 €
# 4. Samsung Galaxy S8 - G950FZ - Prateado 719,99 € 589,99 €
# 5. Samsung Galaxy S8 Dual Sim- G950F-DS - Preto Meia-Noite 477,99 €
# 5. Samsung Galaxy S8+ - G955FZ - Cinzento Orquídea 528 €
# 5. Samsung Galaxy S8 - G950FZ - Preto Meia-Noite 475,90 €
# 5. Smartphone Samsung Galaxy S8 - 64GB - Blue Coral 549,89 €
# 5. Smartphone Samsung Galaxy S8 G950F - 64GB - Preto Meia-Noite 604,49 €
# 5. Smartphone TIM Samsung Galaxy S8 4GB 64 GB Azul 570 €
# 5. Smartphone Telekom Samsung Galaxy S8 Plus 4GB 64 GB Cinzento 493,99 €
# 5. Smartphone Telekom Samsung Galaxy S8 Plus 4GB 64 GB Preto 661 €
# 5. Smartphone Telecom Italia Samsung Galaxy S8+ 4GB 64 GB Cinzento 775 €
# 5. Smartphone Telecom Italia Samsung Galaxy S8+ 4GB 64 GB Prateado 765 €
# 5. Smartphone Telecom Italia Samsung Galaxy S8 4GB 64 GB Cinzento 570 €
# 5. Smartphone Telecom Italia Samsung Galaxy S8 4GB 64 GB Prateado 570 €
# 5. Samsung Galaxy S8 PLUS SM-G955F 4GB RAM 64 GB Preto 528 €
# 8. Samsung Galaxy S9+ - G965FZ - Azul Topázio 969,99 €
# 8. Samsung Galaxy S9+ - G965FZ - Rosa Púrpura 969,99 €
# 8. Samsung Galaxy S9+ - G965FZ - Dourado Amanhecer 969,99 €
# 8. Samsung Galaxy S9+ - G965FZ - Preto Meia-Noite 969,99 €
# 8. Samsung Galaxy S9+ - G965FZ - 256GB - Cinzento Titânio 1 099,99 €
# 8. Samsung Galaxy S9 - G960FZ - Rosa Púrpura 869,99 €
# 8. Samsung Galaxy S9 - G960FZ - Azul Topázio 869,99 €
# 8. Samsung Galaxy S9 - G960FZ - Preto Meia-Noite 869,99 €
# 8. Samsung Galaxy S9 - G960FZ - 256GB - Cinzento Titânio 999,99 €
# 8. Samsung Galaxy S9 - G960FZ - Dourado Amanhecer 869,99 €
# 8. Capa Samsung Clear View para Galaxy S9+ - Preto 59,99 €
# 8. Capa Samsung Led View para Galaxy S9+ - Preto 69,99 €
# 8. Capa Samsung Protective para Galaxy S9+ - Preto 39,99 €
# 8. Capa Book Window 4-OK para Galaxy S9+ - Preto 19,99 €
# 8. Capa Samsung Clear View para Galaxy S9+ - Dourado 59,99 €
# 8. Capa Samsung Clear View para Galaxy S9 - Preto 59,99 €
# 8. Capa Samsung Silicone para Galaxy S9 - Preto 29,99 €
# 8. Capa Book Window 4-OK para Galaxy S9 - Preto 19,99 €
# 8. Capa 4-OK Ultra Slim para Galaxy S9 13,99 €
# 8. Capa Samsung Led View para Galaxy S9 - Preto 69,99 €
# 8. Película Ecrã Vidro Temperado 4-OK para Galaxy S9+ 19,99 €
# 8. Película Ecrã Vidro Temperado 4-OK para Galaxy S9 19,99 €
# 8. Película de Vidro Temperado Advansia para Samsung Galaxy S9 Plus Proteção Total 7,90 €
# 8. Película Vidro Temperado 3D Multishop para Samsung Galaxy S9+ / S9 Plus 8,99 €
# 8. Película Vidro Temperado Multishop para Samsung Galaxy S9+ / S9 Plus 6,99 €
# 3. 969,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Verde 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 1TB - Branco Cerâmico 1 599,99 € 1 549,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Preto 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 512GB - Preto Cerâmico 1 199,99 € 1 149,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Branco 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Prateado Prisma 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 512GB - Branco Cerâmico 1 199,99 € 1 149,99 €
# 7. Samsung Galaxy S10+ - G975FC - 1TB - Preto Cerâmico 1 599,99 € 1 549,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Verde 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Branco 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Preto 849,99 € 749,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Prateado Prisma 849,99 € 749,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Preto 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Branco 849,99 € 749,99 €
# 8. Samsung Galaxy S10 - G973FZ - 128GB - Verde 649,98 €
# 7. Samsung Galaxy S10e - G970FZ - Branco 699,99 € 679,99 €
# 7. Samsung Galaxy S10e - G970FZ - Preto 699,99 € 679,99 €
# 7. Samsung Galaxy S10e - G970FZ - Verde 699,99 € 679,99 €
# 8. Samsung Galaxy S10e - G970FZ - Amarelo 500,85 €
# 8. Smartphone Samsung Galaxy S10E 5.8"" 128Gb Dual Sim Branco 500,85 €
# 8. Capa Samsung Clear para Galaxy S10+ - Transparente 19,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Preto 54,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Preto 29,99 €
# 8. Capa Samsung Led View para Galaxy S10+ - Preto 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Branco 29,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Verde 29,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10+ - Transparente 19,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Verde 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Branco 54,99 €
# 8. Capa Samsung Led View para Galaxy S10+ - Branco 69,99 €
# 8. Capa Samsung Clear para Galaxy S10 - Transparente 19,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10e - Preto 19,99 €
# 8. Película Ecrã Samsung para Galaxy S10 19,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Preto 29,99 €
# 8. Capa Samsung Protective para Galaxy S10+ - Preto 39,99 €
# 8. Capa Samsung Clear View para Galaxy S10 - Preto 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10 - Verde 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10e - Transparente 19,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Azul 29,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Branco 29,99 €
# 8. Capa Samsung Led View para Galaxy S10e - Preto 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10e - Verde 29,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Branco 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Preto 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10 - Preto 19,99 €
# 8. Capa Samsung Led View para Galaxy S10e - Branco 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10e - Branco 29,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Verde 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10 - Transparente 19,99 €
# 8. Capa Samsung Pele para Galaxy S10e - Preto 49,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Verde 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 1TB - Branco Cerâmico 1 599,99 € 1 549,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Preto 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 512GB - Preto Cerâmico 1 199,99 € 1 149,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Branco 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FZ - 128GB - Prateado Prisma 949,99 € 899,99 €
# 7. Samsung Galaxy S10+ - G975FC - 512GB - Branco Cerâmico 1 199,99 € 1 149,99 €
# 7. Samsung Galaxy S10+ - G975FC - 1TB - Preto Cerâmico 1 599,99 € 1 549,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Verde 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Branco 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Preto 849,99 € 749,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Prateado Prisma 849,99 € 749,99 €
# 7. Samsung Galaxy S10 - G973FZ - 512GB - Preto 949,99 € 849,99 €
# 7. Samsung Galaxy S10 - G973FZ - 128GB - Branco 849,99 € 749,99 €
# 8. Samsung Galaxy S10 - G973FZ - 128GB - Verde 649,98 €
# 7. Samsung Galaxy S10e - G970FZ - Branco 699,99 € 679,99 €
# 7. Samsung Galaxy S10e - G970FZ - Preto 699,99 € 679,99 €
# 7. Samsung Galaxy S10e - G970FZ - Verde 699,99 € 679,99 €
# 8. Samsung Galaxy S10e - G970FZ - Amarelo 500,85 €
# 8. Smartphone Samsung Galaxy S10E 5.8"" 128Gb Dual Sim Branco 500,85 €
# 8. Capa Samsung Clear para Galaxy S10+ - Transparente 19,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Preto 54,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Preto 29,99 €
# 8. Capa Samsung Led View para Galaxy S10+ - Preto 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Branco 29,99 €
# 8. Capa Samsung Silicone para Galaxy S10+ - Verde 29,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10+ - Transparente 19,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Verde 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10+ - Branco 54,99 €
# 8. Capa Samsung Led View para Galaxy S10+ - Branco 69,99 €
# 8. Capa Samsung Clear para Galaxy S10 - Transparente 19,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10e - Preto 19,99 €
# 8. Película Ecrã Samsung para Galaxy S10 19,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Preto 29,99 €
# 8. Capa Samsung Protective para Galaxy S10+ - Preto 39,99 €
# 8. Capa Samsung Clear View para Galaxy S10 - Preto 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10 - Verde 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10e - Transparente 19,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Azul 29,99 €
# 8. Capa Samsung Silicone para Galaxy S10 - Branco 29,99 €
# 8. Capa Samsung Led View para Galaxy S10e - Preto 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10e - Verde 29,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Branco 54,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Preto 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10 - Preto 19,99 €
# 8. Capa Samsung Led View para Galaxy S10e - Branco 69,99 €
# 8. Capa Samsung Silicone para Galaxy S10e - Branco 29,99 €
# 8. Capa Samsung Clear View para Galaxy S10e - Verde 54,99 €
# 8. Capa Itskins Spectrumclear para Samsung Galaxy S10 - Transparente 19,99 €
# 8. Capa Samsung Pele para Galaxy S10e - Preto 49,99 €
# 1. 779,99 €
# 5. Apple iPhone 8 - 256GB - Dourado 889,99 €
# 5. Apple iPhone 8 - 64GB - Cinzento Sideral 719,99 €
# 5. Apple iPhone 8 Plus - 64GB - Cinzento Sideral 829,99 €
# 5. Apple iPhone 8 Plus - 64GB - Dourado 829,99 €
# 5. Apple iPhone 8 - 64GB - Prateado 719,99 €
# 5. Apple iPhone 8 - 64GB - Dourado 719,99 €
# 5. Apple iPhone 8 - 256GB - Cinzento Sideral 889,99 €
# 5. Apple iPhone 8 Plus - 256GB - Prateado 999,99 €
# 5. Apple iPhone 8 Plus - 64GB - Prateado 829,99 €
# 5. Apple iPhone 8 Plus - 256GB - Cinzento Sideral 999,99 €
# 5. Apple iPhone 8 - 256GB - Prateado 889,99 €
# 5. Apple iPhone 8 Plus - 256GB - Dourado 999,99 €
# 5. Apple iPhone 8 Plus - 64GB - (Product) Red - Edição Especial 744,90 €
# 5. Apple iPhone 8 - 64GB - (Product) Red - Edição Especial 641,90 €
# 5. Apple iPhone 8 - 256GB - (Product) Red - Edição Especial 768 €
# 5. Apple iPhone 8 Plus - 256GB - (Product) Red - Edição Especial 888 €
# 5. Apple iPhone 8 - 64GB - Cinzento Sideral 829,99 €
# 5. Apple iPhone 8 - 64GB - (Product) Red - Edição Especial 665 €
# 5. Apple iPhone 8 - 64GB - Dourado 829,99 €
# 5. Apple iPhone 8 Plus - 64GB - (Product) Red - Edição Especial 781 €
# 5. Apple iPhone 8 - 64GB - Prateado 829,99 €
# 5. Apple iPhone 8 Plus - 64GB - Cinzento Sideral 939,99 €
# 5. Apple iPhone 8 Plus - 64GB - Dourado 939,99 €
# 5. Apple iPhone 8 Plus - 64GB - Prateado 939,99 €
# 5. Apple iPhone 8 - 256GB - Cinzento Sideral 842,99 €
# 5. Apple iPhone 8 Plus - 256GB - Dourado 1 119,99 €
# 5. Apple iPhone 8 Plus - 256GB - Cinzento Sideral 1 119,99 €
# 5. Apple iPhone 8 Plus - 256GB - Prateado 1 138,40 €
# 5. Apple iPhone 8 Plus - 256GB - (Product) Red - Edição Especial 1 186 €
# 5. Apple iPhone 8 - 256GB - (Product) Red - Edição Especial 1 009,99 €
# 5. Apple iPhone 8 - 256GB - Prateado 1 009,99 €
# 5. Apple iPhone 8 - 256GB - Dourado 1 009,99 €
# 5. Apple iPhone X - 256GB - Cinzento Sideral 1 229,99 €
# 5. Apple iPhone X - 256GB - Prateado 1 229,99 €
# 5. Apple iPhone X - 64GB - Cinzento Sideral 1 059,99 €
# 5. Apple iPhone X - 64GB - Prateado 1 059,99 €
# 4. Apple iPhone X - 64GB - Prateado 1 179,99 € 1 029,99 €
# 5. Apple iPhone X - 64GB - Cinzento Sideral 993,10 €
# 5. Apple iPhone X 64GB Prateado 910 €
# 5. Apple iPhone X 256GB Cinzento 1 060 €
# 5. Apple iPhone X 64GB Cinzento 910 €
# 5. Apple iPhone X 256GB Prateado 1 060 €
# 5. Apple iPhone XR - 64GB - Preto 879,99 €
# 5. Apple iPhone XR - 64GB - Branco 879,99 €
# 5. Apple iPhone XR - 64GB - Amarelo 879,99 €
# 5. Apple iPhone XR - 128GB - Preto 939,99 €
# 5. Apple iPhone XR - 256GB - Preto 1 049,99 €
# 5. Apple iPhone XR - 128GB - Branco 939,99 €
# 5. Apple iPhone XR - 128GB - Azul 939,99 €
# 5. Apple iPhone XR - 64GB - Azul 879,99 €
# 5. Apple iPhone XR - 64GB - Coral 879,99 €
# 5. Apple iPhone XR - 64GB - (Product) Red 879,99 €
# 5. Apple iPhone XR - 128GB - Amarelo 939,99 €
# 5. Apple iPhone XR - 256GB - Coral 1 049,99 €
# 5. Apple iPhone XR - 256GB - Branco 1 049,99 €
# 5. Apple iPhone XR - 128GB - Coral 939,99 €
# 5. Apple iPhone XR - 256GB - Azul 1 049,99 €
# 5. Apple iPhone XR - 256GB - Amarelo 1 049,99 €
# 5. Apple iPhone XR - 256GB - (Product) Red 979,99 €
# 5. Apple iPhone XR - 128GB - (Product) Red 846,87 €
# 5. Apple iPhone XR 128GB Vermelho 796 €
# 5. Apple iPhone XR 64GB Coral 738 €
# 5. Apple iPhone X - 64GB - Prateado 1 179,99 €
# 5. Apple iPhone X - 64GB - Cinzento Sideral 1 179,99 €
# 5. Apple iPhone X - 256GB - Cinzento Sideral 1 359,99 €
# 5. Apple iPhone X - 64GB - Cinzento Sideral 1 179,99 €
# 5. Apple iPhone X - 256GB - Prateado 1 102,50 €
# 5. Apple iPhone X - 64GB - Prateado 1 009 €
# 5. Apple iPhone X 64GB Cinzento 1 009 €
# 5. Apple iPhone X 256GB Cinzento 1 199 €
# 5. Apple iPhone X 256GB Prateado 1 148,90 €
# 5. Apple iPhone X 64GB Prateado 999 €
# 5. Apple iPhone XR 64GB Azul 896,30 €
# 5. Apple iPhone XR 64GB Amarelo 893,50 €
# 5. Apple iPhone XR 64GB Preto 770 €
# 5. Apple iPhone XR 256GB Azul 839 €
# 5. Apple iPhone XR 128GB Azul 802 €
# 5. Apple iPhone XR 256GB Coral 940 €
# 5. Apple iPhone XR 128GB Amarelo 797 €
# 5. Apple iPhone XR 256GB Vermelho 1 060,70 €
# 5. Apple iPhone XR 256GB Preto 1 155,69 €
# 5. Apple iPhone XR 128GB Preto 807 €
# 5. Apple iPhone XR 256GB Branco 1 060,70 €
# 5. Apple iPhone XR 128GB Branco 810 €
# 5. Apple iPhone XR 64GB Vermelho 769 €
# 5. Apple iPhone XR 64GB Amarelo 747 €
# 5. Apple iPhone XR 64GB Azul 747 €
# 5. Apple iPhone XR 64GB Preto 769 €
# 5. Apple iPhone XR 64GB Branco 765 €
# 5. Apple iPhone XS - 64GB - Dourado 1 179,99 €
# 5. Apple iPhone XS - 64GB - Prateado 1 179,99 €
# 5. Apple iPhone XS Max- 64GB - Dourado 1 279,99 €
# 5. Apple iPhone XS Max- 64GB - Cinzento Sideral 1 279,99 €
# 5. Apple iPhone XS - 64GB - Cinzento Sideral 1 179,99 €
# 5. Apple iPhone XS - 256GB - Cinzento Sideral 1 349,99 €
# 5. Apple iPhone XS Max- 256GB - Prateado 1 449,99 €
# 5. Apple iPhone XS - 256GB - Prateado 1 349,99 €
# 5. Apple iPhone XS Max- 256GB - Cinzento Sideral 1 449,99 €
# 5. Apple iPhone XS Max- 256GB - Dourado 1 449,99 €
# 5. Apple iPhone XS Max- 64GB - Prateado 1 279,99 €
# 5. Apple iPhone XS - 512GB - Dourado 1 579,99 €
# 5. Apple iPhone XS - 256GB - Dourado 1 349,99 €
# 5. Apple iPhone XS Max- 512GB - Dourado 1 679,99 €
# 5. Apple iPhone XS Max- 512GB - Prateado 1 679,99 €
# 5. Apple iPhone XS - 512GB - Cinzento Sideral 1 240 €
# 5. Apple iPhone XS - 512GB - Prateado 1 579,99 €
# 5. Apple iPhone XS Max- 512GB - Cinzento Sideral 1 679,99 €
# 5. Apple iPhone XS 512GB Dourado 1 602,80 €
# 5. Apple iPhone XS Max 64GB Dourado 1 129,85 €
# 5. Apple iPhone XS Max 64GB Cinzento 1 096 €
# 5. Apple iPhone XS 64GB Cinzento 1 006,73 €
# 5. Apple iPhone XS Max 256GB Dourado 1 285,61 €
# 5. Apple iPhone XS Max 256GB Prateado 1 250,21 €
# 5. Apple iPhone XS Max 64GB Prateado 1 117,88 €
# 5. Apple iPhone XS 64GB Prateado 984,71 €
# 5. Apple iPhone XS 64GB Dourado 1 011 €
# 5. Apple iPhone XS 256GB Dourado 1 167,61 €
# 5. Apple iPhone XS Max 512GB Dourado 1 795,90 €
# 5. Apple iPhone XS Max 512GB Prateado 1 565 €
# 5. Apple iPhone XS Max 512GB Cinzento 1 565 €
# 5. Apple iPhone XS Max 256GB Dourado 1 355 €
# 5. Apple iPhone XS Max 256GB Prateado 1 471,10 €
# 5. Apple iPhone XS Max 256GB Cinzento 1 482,10 €
# 5. Apple iPhone XS 512GB Prateado 1 602,80 €
# 5. Apple iPhone XS 512GB Cinzento 1 309,88 €
# 5. Apple iPhone XS 256GB Dourado 1 382,20 €
# 5. Apple iPhone XS 256GB Prateado 1 474 €
# 5. Apple iPhone XS 256GB Cinzento 1 484,80 €
# 5. Apple iPhone XS Max 64GB Cinzento 1 117,42 €
# 3. 1 049,99 €
# 3. 1 179,99 €
# 5. Apple iPhone XS - 64GB - Dourado 1 179,99 €
# 5. Apple iPhone XS - 64GB - Prateado 1 179,99 €
# 5. Apple iPhone XS Max- 64GB - Dourado 1 279,99 €
# 5. Apple iPhone XS Max- 64GB - Cinzento Sideral 1 279,99 €
# 5. Apple iPhone XS - 64GB - Cinzento Sideral 1 179,99 €
# 5. Apple iPhone XS - 256GB - Cinzento Sideral 1 349,99 €
# 5. Apple iPhone XS Max- 256GB - Prateado 1 449,99 €
# 5. Apple iPhone XS - 256GB - Prateado 1 349,99 €
# 5. Apple iPhone XS Max- 256GB - Cinzento Sideral 1 449,99 €
# 5. Apple iPhone XS Max- 256GB - Dourado 1 449,99 €
# 5. Apple iPhone XS Max- 64GB - Prateado 1 279,99 €
# 5. Apple iPhone XS - 512GB - Dourado 1 579,99 €
# 5. Apple iPhone XS - 256GB - Dourado 1 349,99 €
# 5. Apple iPhone XS Max- 512GB - Dourado 1 679,99 €
# 5. Apple iPhone XS Max- 512GB - Prateado 1 679,99 €
# 5. Apple iPhone XS - 512GB - Cinzento Sideral 1 240 €
# 5. Apple iPhone XS - 512GB - Prateado 1 579,99 €
# 5. Apple iPhone XS Max- 512GB - Cinzento Sideral 1 679,99 €
# 5. Apple iPhone XS 512GB Dourado 1 602,80 €
# 5. Apple iPhone XS Max 64GB Dourado 1 129,85 €
# 5. Apple iPhone XS Max 64GB Cinzento 1 096 €
# 5. Apple iPhone XS 64GB Cinzento 1 006,73 €
# 5. Apple iPhone XS Max 256GB Dourado 1 285,61 €
# 5. Apple iPhone XS Max 256GB Prateado 1 250,21 €
# 5. Apple iPhone XS Max 64GB Prateado 1 117,88 €
# 5. Apple iPhone XS 64GB Prateado 984,71 €
# 5. Apple iPhone XS 64GB Dourado 1 011 €
# 5. Apple iPhone XS 256GB Dourado 1 167,61 €
# 5. Apple iPhone XS Max 512GB Dourado 1 795,90 €
# 5. Apple iPhone XS Max 512GB Prateado 1 565 €
# 5. Apple iPhone XS Max 512GB Cinzento 1 565 €
# 5. Apple iPhone XS Max 256GB Dourado 1 355 €
# 5. Apple iPhone XS Max 256GB Prateado 1 471,10 €
# 5. Apple iPhone XS Max 256GB Cinzento 1 482,10 €
# 5. Apple iPhone XS 512GB Prateado 1 602,80 €
# 5. Apple iPhone XS 512GB Cinzento 1 309,88 €
# 5. Apple iPhone XS 256GB Dourado 1 382,20 €
# 5. Apple iPhone XS 256GB Prateado 1 474 €
# 5. Apple iPhone XS 256GB Cinzento 1 484,80 €
# 5. Apple iPhone XS Max 64GB Cinzento 1 117,42 €
# 3. 1 179,99 €
# 3. 1 349,99 €
# 5. Apple iPhone XR - 64GB - Preto 879,99 €
# 5. Apple iPhone XR - 64GB - Branco 879,99 €
# 5. Apple iPhone XR - 64GB - Amarelo 879,99 €
# 5. Apple iPhone XR - 128GB - Preto 939,99 €
# 5. Apple iPhone XR - 256GB - Preto 1 049,99 €
# 5. Apple iPhone XR - 128GB - Branco 939,99 €
# 5. Apple iPhone XR - 128GB - Azul 939,99 €
# 5. Apple iPhone XR - 64GB - Azul 879,99 €
# 5. Apple iPhone XR - 64GB - Coral 879,99 €
# 5. Apple iPhone XR - 64GB - (Product) Red 879,99 €
# 5. Apple iPhone XR - 128GB - Amarelo 939,99 €
# 5. Apple iPhone XR - 256GB - Coral 1 049,99 €
# 5. Apple iPhone XR - 256GB - Branco 1 049,99 €
# 5. Apple iPhone XR - 128GB - Coral 939,99 €
# 5. Apple iPhone XR - 256GB - Azul 1 049,99 €
# 5. Apple iPhone XR - 256GB - Amarelo 1 049,99 €
# 5. Apple iPhone XR - 256GB - (Product) Red 979,99 €
# 5. Apple iPhone XR - 128GB - (Product) Red 846,87 €
# 5. Apple iPhone XR 128GB Vermelho 796 €
# 5. Apple iPhone XR 64GB Coral 738 €
# 5. Apple iPhone XR 64GB Azul 896,30 €
# 5. Apple iPhone XR 64GB Amarelo 893,50 €
# 5. Apple iPhone XR 64GB Preto 770 €
# 5. Apple iPhone XR 256GB Azul 839 €
# 5. Apple iPhone XR 128GB Azul 802 €
# 5. Apple iPhone XR 256GB Coral 940 €
# 5. Apple iPhone XR 128GB Amarelo 797 €
# 5. Apple iPhone XR 256GB Vermelho 1 060,70 €
# 5. Apple iPhone XR 256GB Preto 1 155,69 €
# 5. Apple iPhone XR 128GB Preto 807 €
# 5. Apple iPhone XR 256GB Branco 1 060,70 €
# 5. Apple iPhone XR 128GB Branco 810 €
# 5. Apple iPhone XR 64GB Vermelho 769 €
# 5. Apple iPhone XR 64GB Amarelo 747 €
# 5. Apple iPhone XR 64GB Azul 747 €
# 5. Apple iPhone XR 64GB Preto 769 €
# 5. Apple iPhone XR 64GB Branco 765 €
# 3. 1 049,99 €
# 5. Consola Sony PS4 Slim 1TB + Uncharted 4 + Horizon Zero Dawn 369,99 €
# 5. Consola Sony PS4 Slim 1TB + Uncharted 4 + GTA V 369,99 €
# 5. Consola Sony PS4 Slim 1TB + Ratchet & Clank + Crash Bandicoot N. Sane Trilogy 349,99 €
# 4. Consola Sony PS4 Slim 500GB Dourada (Gold) - Edição Especial 2 Comandos 389,99 € 349,99 €
# 5. Consola Sony PS4 Pro 1TB + Voucher PlayStation 10€ 399,99 €
# 5. Consola Sony PS4 Slim 500GB Preta 299,99 €
# 5. Consola Sony PS4 Slim 1TB 478,99 €
# 5. Consola Sony PS4 Slim 500GB Prateada (Sliver) - Edição Especial 2 Comandos 398,99 €
# 5. Pack Consola Sony PS4 Slim 1TB + Ratchet & Clank + Crash Bandicoot N. Sane Trilogy + FIFA 17 399,99 €
# 5. Pack Consola Sony PS4 Pro 1TB + GTA V 429,90 €
# 5. Consola Sony PS4 Slim 500GB Branca / Glacier White 342,03 €
# 5. Consola Sony PS4 Slim 1TB + The Last Guardian 399,99 €
# 5. Consola Sony PS4 Slim 1TB + Final Fantasy XV - Edição Limitada 499,99 €
# 5. Consola Sony PS4 Pro 1TB 399 €
# 5. Consola Sony PS4 Slim 1TB + Call of Duty: Infinite Warfare 379,99 €
# 5. Consola Sony PS4 Slim 1TB + Mafia III 369,99 €
# 5. Pack Consola Sony PS4 Slim 500GB + Pro Evolution Soccer 2017 344,99 €
# 5. Consola Sony PS4 1TB + Street Fighter V 369,99 €
# 5. Ni no Kuni II: Revenant Kingdom: Princes's Edition PS4 94,99 €
# 5. Ni no Kuni II: Revenant Kingdom: King's Edition PS4 159,99 €
# 5. Destiny 2 Collector's Edition PS4 249,99 €
# 5. Star Wars: Battlefront II: Elite Trooper Deluxe Edition PS4 89,99 €
# 5. Thrustmaster Volante TX Ferrari 458 Racing Xbox One / PC 349,99 €
# 5. Thrustmaster Volante TMX Force Feedback - Xbox One 175,65 €
# 5. Thrustmaster TX Racing Wheel Leather Edition Xbox One 399,30 €
# 5. Thrustmaster Ferrari 458 Spider Racing Wheel 94,95 €
# 5. Thrustmaster TMX Pro Racing Wheel Xbox One 219,94 €
# 5. Destiny 2 Limited Edition Xbox One 109,99 €
# 5. Destiny 2 Collector’s Edition Xbox One 249,99 €
# 4. Forza Motosport 7 Ultimate Edition Xbox One 99,99 € 84,99 €
# 5. Star Wars: Battlefront II: Elite Trooper Deluxe Edition Xbox One 89,99 €
# 5. Dark Souls III Collector's Edition Xbox One 90 €
# 5. Syberia 3 Collector's Edition Xbox One 129,99 €
# 5. Stardew Valley Collector's Edition XBox One 30,99 €
# 5. Deus Ex: Mankind Divided Collector's Edition Xbox One 89 €
# 5. Mafia III Collector's Edition Xbox One 159,99 €
# 5. Hitman Collector's Edition Xbox One 122 €
# 5. Tekken 7 Collector's Edition Xbox One 152,99 €
# 5. Rocket League Collector's Edition Xbox One 29,95 €
# 5. Halo 5: Guardians Limited Collector's Edition Xbox One 199,99 €
# 5. Destiny 2 Collector’s Edition Xbox One 249,99 €
# 5. Assassin's Creed Origins Gods Collector's Edition Xbox One 129,99 €
# 5. Project C.A.R.S. 2 Collector's Edition Xbox One 159,99 €
# 5. South Park: The Fractured But Whole Collector's Edition Xbox One 99,99 €
# 5. Dragon Ball: Xenoverse 2 Collector's Edition Xbox One 159,99 €
# 5. Metal Gear Solid V: The Phantom Pain Collector's Edition Xbox One 129,99 €

# %%
df = pd.read_csv('data/resultados_black_friday_arquivo.csv')

result_list = process_row_FNAC(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']

df_result.to_csv('data/products_extracted_prices_FNAC_Black_Friday.csv', index=False)
# Out:
# 2. 349,99 € 299 €
# 2. 349,99 € 299 €
# 7. Apple iPhone 8 - 64GB - Cinzento Sideral 549,99 € 499,99 €
# 7. Apple iPhone XS - 64GB - Cinzento Sideral 1 069,99 € 829,99 €
# 7. Apple iPhone 7 - 32GB (Preto Mate) 449,99 € 349,99 €
# 7. Apple iPhone 8 - 64GB - Prateado 549,99 € 499,99 €
# 7. Apple iPhone 7 - 32GB (Rosa Dourado) 449,99 € 349,99 €
# 7. Apple iPhone 7 - 32GB (Dourado) 449,99 € 349,99 €
# 7. Apple iPhone 7 - 32GB (Prateado) 449,99 € 349,99 €
# 7. Apple iPhone 8 - 64GB - Dourado 549,99 € 499,99 €
# 7. Apple iPhone XS - 64GB - Dourado 1 069,99 € 829,99 €
# 7. Apple iPhone XS - 64GB - Prateado 1 069,99 € 829,99 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Prateado 1 279 € 999 €
# 7. Apple MacBook Pro 13'' Retina i5-2,4GHz | 8GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Prateado 2 099 € 1 784 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Apple iPad Pro 11'' - 64GB WiFi - Cinzento Sideral 909 € 799 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 8. Apple iPad Pro 11'' - 256GB WiFi - Cinzento Sideral 1 079 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 8. Apple MacBook Pro 13'' Retina i7-2,8GHz | 16GB | 512GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 949 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 8. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 789 €
# 8. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 799 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 8. Apple iPhone XR - 64GB - Preto 610 €
# 7. Apple Iphone 6 - 16GB - Cinzento Sideral - Recondicionado Grade A + Capa + Película 269,99 € 169,99 €
# 7. Apple iPhone 7 - 32GB - Cinzento Sideral - Recondicionado Grade A 529,99 € 279,99 €
# 8. Apple iPhone XR - 64GB - Branco 610 €
# 8. Apple iPhone 11 - 128GB - Preto 793,99 €
# 7. Apple iphone 7 - 32GB - Prateado - Recondicionado Grade A 329,99 € 279,99 €
# 7. Apple iPhone 7 - 32GB (Preto Mate) 449,99 € 349,99 €
# 8. Apple iPhone 11 Pro - 64GB - Cinzento Sideral 1 062 €
# 7. Apple iPhone 8 - 64GB - Cinzento Sideral 549,99 € 499,99 €
# 8. Apple iPhone 11 - 64GB - Preto 829,99 €
# 7. Apple iPad - 32GB Wi-Fi - Cinzento Sideral 369 € 295 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Cinzento Sideral 2019 499 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Dourado 2019 499 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 64GB - Cinzento Sideral 2019 579 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Prateado 2019 499 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 256GB - Cinzento Sideral 2019 749 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 8. Apple iPad Pro 12.9'' - 256GB WiFi - Cinzento Sideral 1 299 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 128GB | 8GB 1 069 € 799 €
# 7. Computador Portátil Lenovo Ideapad S340-15API 699,99 € 429,99 €
# 7. Computador Portátil HP 15-da1045np 749,99 € 549,99 €
# 7. Computador Portátil HP 15-da1050np 649,99 € 499,99 €
# 7. Computador Portátil Asus F509FB-58CM1CB1 649,99 € 499,99 €
# 7. Computador Portátil Microsoft Surface Laptop 3 13.5'' - Platina - Core i5 | 128GB | 8GB 1 169 € 935 €
# 7. Computador Portátil Lenovo Ideapad C340-14API-301 499,99 € 399,99 €
# 7. Desktop HP Pavilion TP01-0019np 599,99 € 449,99 €
# 7. Computador Portátil Acer Aspire 5 A514-52-59BU - Prateado 749,99 € 549,99 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Preto - Core i5 | 256GB | 8GB 1 399 € 1 049 €
# 7. Computador Portátil Microsoft Surface Laptop 3 13.5'' - Preto - Core i5 | 256GB | 8GB 1 499 € 1 199 €
# 8. Computador Portátil HP Pavilion x360 14-dh0012np 749,99 €
# 8. Computador Portátil Asus Laptop X571GT-79A15PB1 1 199,99 €
# 8. Apple MacBook Pro 15'' Retina i9-2,3GHz | 16GB | 512GB | Radeon Pro 560X com Touch Bar e Touch ID - Prateado 3 299 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 8. Computador Portátil Lenovo ideapad D330-10IGM | Celeron N4000 | 4GB 329,99 €
# 7. Computador Portátil HP Pavilion x360 14-dh0004np 599,99 € 449,99 €
# 8. Pack Fnac Lenovo Ideapad S130-14IGM + Mochila + Rato + Office 365 - 1 ano 309,66 €
# 7. Computador Portátil Lenovo Ideapad C340-14API-301 499,99 € 399,99 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 256GB | 8GB 1 399 € 1 049 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Prateado 1 279 € 999 €
# 8. Apple MacBook Pro 13'' Retina i7-2,8GHz | 8GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 459 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 7. Computador Portátil Asus F509FB-58CM1CB1 649,99 € 499,99 €
# 8. Computador Portátil Lenovo Ideapad S145-15AST 338,38 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 256GB | 8GB 1 399 € 1 049 €
# 7. Computador Portátil Microsoft Surface Laptop 3 13.5'' - Preto - Core i5 | 256GB | 8GB 1 499 € 1 199 €
# 8. Microsoft Surface Go - Pentium Gold 4415Y | 128GB | 8GB 666,76 €
# 7. Computador Portátil Microsoft Surface Pro 6 - Platina - Core i5 | 128GB | 8GB 1 069,99 € 969,99 €
# 7. Computador Portátil HP 15-da1050np 649,99 € 499,99 €
# 7. Computador Portátil HP 15-da1045np 749,99 € 549,99 €
# 7. Computador Portátil Lenovo Ideapad S340-15API 699,99 € 429,99 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 128GB | 8GB 1 069 € 799 €
# 8. Computador Portátil Innjoo A100 Pro | Intel Atom® x5-Z8350 | 64GB 199,99 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 8. Apple MacBook Air 13'' Retina | i5-1,6GHz | 16GB | 256GB - Prateado 1 769 €
# 8. Apple MacBook Pro 15'' Retina i9-2,4GHz | 16GB | 256GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 159 €
# 8. Computador Portátil HP 13-aq0002np 1 199,99 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | Intel Celeron N4000 | 128GB SSD 399,99 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 8. Apple MacBook Pro 13'' Retina i5-2,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Prateado 2 339 €
# 8. Computador Portátil Asus VivoBook X512FB-58AM1SB1 699,99 €
# 8. Computador Portátil Gaming OMEN by HP 15-dc0057np 1 299,99 €
# 8. Computador Portátil Microsoft Surface Pro X 13'' - Preto - SQ1 | 256GB | 8GB | 4G 1 499 €
# 8. Computador Portátil Microsoft Surface Pro X 13'' - Preto - SQ1 | 128GB | 8GB | 4G 1 169 €
# 8. Computador Portátil Microsoft Surface Pro X 13'' - Preto - SQ1 | 256GB | 16GB | 4G 1 699 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | Intel Celeron N4000 | 128GB SSD 399,99 €
# 7. Computador Portátil Asus F509FB-58CM1CB1 649,99 € 499,99 €
# 8. Computador Portátil Asus F509UB-37AM1SB1 499,99 €
# 7. Computador Portátil Gaming Acer Nitro 5 AN515-43-R58R - Preto 799,99 € 639,99 €
# 7. Computador Portátil Acer Aspire 5 A514-52-59BU - Prateado 749,99 € 549,99 €
# 8. Computador Portátil Insys WH8-N1560 349,99 €
# 8. Computador Portátil Acer Swift 3 SF314-57-54A4 799,99 €
# 8. Apple MacBook Pro 15'' Retina i9-2,4GHz | 16GB | 256GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 159 €
# 8. Apple MacBook Pro 15'' Retina i9-2,3GHz | 32GB | 512GB | Radeon Pro Vega 20 com Touch Bar e Touch ID - Cinzento Sideral 4 199 €
# 8. Apple MacBook Pro 15'' Retina i9-2,3GHz | 16GB | 512GB | Radeon Pro 560X com Touch Bar e Touch ID - Prateado 3 299 €
# 8. Computador Portátil Gaming Asus ROG Mothership GZ700GX-99D28CP1 6 399,99 €
# 8. Apple MacBook Pro 15'' Retina i9-2,3GHz | 32GB | 1TB | Radeon Pro Vega 16 com Touch Bar e Touch ID - Prateado 4 321,40 €
# 8. Apple MacBook Pro 15'' Retina i9-2,3GHz | 16GB | 512GB | Radeon Pro 560X com Touch Bar e Touch ID - Cinzento Sideral 2 559,99 €
# 7. Computador Portátil HP 15-da1045np 749,99 € 549,99 €
# 8. Computador Portátil HP Pavilion 15-cs0007np 1 149,99 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Computador Portátil Gaming Lenovo Legion Y540-15IRH-PG0- 901 1 399,99 € 1 049,99 €
# 8. Computador Portátil Acer Swift 5 SF515-51T-728Y | Core i7-8565U | 256GB 1 099,99 €
# 8. Computador Portátil HP 15-da0011np 799,99 €
# 8. Computador Portátil Gaming Acer Nitro 5 AN515-54-76JN 1 099,99 €
# 8. Computador Portátil Gaming OMEN by HP 15-dc0056np 1 299,99 €
# 8. Apple MacBook Pro 13'' Retina i7-2,8GHz | 8GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 459 €
# 8. Computador Portátil Lenovo Yoga S730-13IWL | i7-8565U | 1TB SSD 1 799,99 €
# 7. Computador Portátil HP 15-da1050np 649,99 € 499,99 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 128GB | 8GB 1 069 € 799 €
# 7. Computador Portátil Asus F509FB-58CM1CB1 649,99 € 499,99 €
# 8. Apple MacBook Pro 13'' Retina i5-2,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Prateado 2 339 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 8. Apple MacBook Pro 13'' Retina i5-2,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 339 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | Intel Celeron N4000 | 128GB SSD 399,99 €
# 8. Computador Portátil Insys WH8-N1560 349,99 €
# 8. Computador Portátil Acer Swift 1 SF114-32-C74S 349,99 €
# 8. Computador Portátil Insys CD9-G148 349,99 €
# 8. Computador Portátil Lenovo ideapad D330-10IGM | Celeron N4000 | 4GB 329,99 €
# 8. Pack Fnac Lenovo Ideapad S130-14IGM + Mochila + Rato + Office 365 - 1 ano 309,66 €
# 8. HP Stream 11-r000np (Azul Cobalto) 299,99 €
# 8. HP Stream 11-d001np (Azul Céu) 289,99 €
# 8. Computador Portátil Lenovo Yoga 330-11IGM-987 | Celeron N4000 | 4GB + Office 365 Pessoal - 1 Ano 421,07 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | N4000 | 4GB + Office 365 Pessoal - 1 Ano 289,99 €
# 8. Microsoft Surface Go - Pentium Gold 4415Y | 64GB | 4GB 459 €
# 8. Microsoft Surface Go - Pentium Gold 4415Y | 128GB | 8GB 666,76 €
# 8. Computador Portátil Lenovo ideapad D330-10IGM | Celeron N4000 | 4GB 329,99 €
# 8. Computador Portátil Microsoft Surface Go - Pentium Gold 4415Y | 128GB | 8GB | 4G LTE 749 €
# 8. Computador Portátil Lenovo YOGA Book C930 1 432,78 €
# 8. Portátil HP x2 10-p001np 299,99 €
# 8. HP x2 10-p000np 299,99 €
# 8. Portátil Híbrido Lenovo D330 N5000 4GB 10.1" Cinzento 420,70 €
# 8. Portátil Híbrido ASUS T103HAF Mini x5-Z8350 4GB 10.1" Cinzento 436,89 €
# 8. Portátil ASUS E203MA-FD048TS N4000 64GB 11.6" Preto 296,95 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | Intel Celeron N4000 | 128GB SSD 399,99 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Computador Portátil Microsoft Surface Pro 7 - Platina - Core i5 | 128GB | 8GB 1 069 € 799 €
# 8. Apple MacBook Pro 13'' Retina i5-2,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Prateado 2 339 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 8. Apple MacBook Pro 13'' Retina i5-2,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 339 €
# 7. Computador Portátil Acer Aspire 5 A514-52-59BU - Prateado 749,99 € 549,99 €
# 7. Computador Portátil HP 15-da1050np 649,99 € 499,99 €
# 7. Computador Portátil HP 15-da1045np 749,99 € 549,99 €
# 8. Computador Portátil HP Pavilion 15-cs0007np 1 149,99 €
# 7. Computador Portátil Asus F509FB-58CM1CB1 649,99 € 499,99 €
# 7. Computador Portátil Lenovo Ideapad S340-15API 699,99 € 429,99 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 8. Computador Portátil Asus F509UB-37AM1SB1 499,99 €
# 7. Computador Portátil Gaming Lenovo Legion Y540-15IRH-PG0- 901 1 399,99 € 1 049,99 €
# 7. Computador Portátil Gaming Acer Nitro 5 AN515-43-R58R - Preto 799,99 € 639,99 €
# 8. Computador Portátil Acer Swift 5 SF515-51T-728Y | Core i7-8565U | 256GB 1 099,99 €
# 8. Computador Portátil Gaming MSI GP75 Leopard 9SE-1091PT 1 899,99 €
# 8. Computador Portátil Gaming OMEN by HP 17-an100np 1 399,99 €
# 8. Computador Portátil Gaming HP Pavilion 17-cd0001np 1 399,99 €
# 7. Computador Portátil LG Gram 17Z990-V.AP77P 1 999,99 € 1 599,99 €
# 8. Computador Portátil Gaming Asus ROG Mothership GZ700GX-99D28CP1 6 399,99 €
# 8. Computador Portátil Lenovo Legion Y740-17ICHg | i7-8750H | 32GB | NVIDIA GeForce RTX 2070 2 249,99 €
# 8. Portátil Gaming Asus ROG G703GS-78D07CB1 2 863,07 €
# 8. Computador Portátil Gaming  Asus ROG G703GS-78D07CB2 1 999,90 €
# 8. Computador Portátil HP Envy 17-bw0001np 1 499,99 €
# 8. Portátil Gaming Asus ROG GL703VD-77A05 1 699,99 €
# 8. Computador Portátil HP 15-da0011np 799,99 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 8. Computador Portátil Innjoo A100 Pro | Intel Atom® x5-Z8350 | 64GB 199,99 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 8. Computador Portátil HP 15-da1014np 549,99 €
# 8. Computador Portátil Lenovo Ideapad S130-14IGM | Intel Celeron N4000 | 128GB SSD 399,99 €
# 8. Computador Portátil HP Pavilion x360 14-dh0012np 749,99 €
# 8. Apple MacBook Pro 13'' Retina i7-2,8GHz | 16GB | 512GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 949 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple iPhone 8 - 64GB - Cinzento Sideral 549,99 € 499,99 €
# 7. Apple iPhone XS - 64GB - Cinzento Sideral 1 069,99 € 829,99 €
# 7. Apple iPhone 7 - 32GB (Preto Mate) 449,99 € 349,99 €
# 7. Apple iPhone 8 - 64GB - Prateado 549,99 € 499,99 €
# 7. Apple iPhone 7 - 32GB (Rosa Dourado) 449,99 € 349,99 €
# 7. Apple iPhone 7 - 32GB (Dourado) 449,99 € 349,99 €
# 7. Apple iPhone 7 - 32GB (Prateado) 449,99 € 349,99 €
# 7. Apple iPhone 8 - 64GB - Dourado 549,99 € 499,99 €
# 7. Apple iPhone XS - 64GB - Dourado 1 069,99 € 829,99 €
# 7. Apple iPhone XS - 64GB - Prateado 1 069,99 € 829,99 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Prateado 1 279 € 999 €
# 7. Apple MacBook Pro 13'' Retina i5-2,4GHz | 8GB | 256GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Prateado 2 099 € 1 784 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 7. Apple iPad Pro 11'' - 64GB WiFi - Cinzento Sideral 909 € 799 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Prateado 1 549 € 1 199 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 8. Apple iPad Pro 11'' - 256GB WiFi - Cinzento Sideral 1 079 €
# 7. Apple MacBook Air 13'' i5-1,8GHz | 8GB | 128GB 1 129 € 839 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 2 039 € 1 729 €
# 7. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 549 € 1 199 €
# 8. Apple MacBook Pro 13'' Retina i7-2,8GHz | 16GB | 512GB | Intel Iris Plus Graphics 655 com Touch Bar e Touch ID - Cinzento Sideral 2 949 €
# 7. Apple MacBook Pro 15'' Retina i7-2,6GHz | 16GB | 512GB | Radeon Pro 555X com Touch Bar e Touch ID - Cinzento Sideral 3 040,27 € 2 349 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Cinzento Sideral 1 279 € 999 €
# 8. Apple MacBook Pro 13'' Retina i5-1,4GHz | 16GB | 128GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 789 €
# 8. Apple MacBook Pro 13'' Retina i5-1,4GHz | 8GB | 256GB | Intel Iris Plus Graphics 645 com Touch Bar e Touch ID - Cinzento Sideral 1 799 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 256GB - Cinzento Sideral 1 529 € 1 289 €
# 7. Apple MacBook Air 13'' Retina | i5-1,6GHz | 8GB | 128GB - Dourado 1 279 € 999 €
# 8. Apple iPhone XR - 64GB - Preto 610 €
# 7. Apple Iphone 6 - 16GB - Cinzento Sideral - Recondicionado Grade A + Capa + Película 269,99 € 169,99 €
# 7. Apple iPhone 7 - 32GB - Cinzento Sideral - Recondicionado Grade A 529,99 € 279,99 €
# 8. Apple iPhone XR - 64GB - Branco 610 €
# 8. Apple iPhone 11 - 128GB - Preto 793,99 €
# 7. Apple iphone 7 - 32GB - Prateado - Recondicionado Grade A 329,99 € 279,99 €
# 7. Apple iPhone 7 - 32GB (Preto Mate) 449,99 € 349,99 €
# 8. Apple iPhone 11 Pro - 64GB - Cinzento Sideral 1 062 €
# 7. Apple iPhone 8 - 64GB - Cinzento Sideral 549,99 € 499,99 €
# 8. Apple iPhone 11 - 64GB - Preto 829,99 €
# 7. Apple iPad - 32GB Wi-Fi - Cinzento Sideral 369 € 295 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Cinzento Sideral 2019 499 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Dourado 2019 499 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 64GB - Cinzento Sideral 2019 579 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Prateado 2019 499 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 256GB - Cinzento Sideral 2019 749 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 8. Apple iPad Pro 12.9'' - 256GB WiFi - Cinzento Sideral 1 299 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 7. Tablet Huawei MediaPad T3 10 - 16GB Wi-Fi - Space Gray 199,99 € 144,99 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 7. Tablet Samsung T290 Galaxy Tab A 2019 8.0'' Wi-Fi - 32GB - Preto 169,99 € 129,99 €
# 7. Tablet Alcatel 1T 7.0'' - 8GB - Wi-Fi - Premium Black 69,99 € 44,99 €
# 7. Apple iPad Pro 11'' - 64GB WiFi - Cinzento Sideral 909 € 799 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 8. Apple iPad Pro 11'' - 256GB WiFi - Cinzento Sideral 1 079 €
# 8. Tablet Lenovo Tab E7 TB-7104F 7" - 16GB - Wi-Fi 99,99 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Prateado 2019 499 €
# 7. Tablet Huawei MediaPad T3 10 - 16GB Wi-Fi - Space Gray 199,99 € 144,99 €
# 7. Tablet Samsung T290 Galaxy Tab A 2019 8.0'' Wi-Fi - 32GB - Cinzento 169,99 € 129,99 €
# 8. Tablet Samsung Galaxy Tab S6 10.5'' - T860 - Wi-Fi - 256GB - Mountain Gray 669,99 €
# 7. Tablet Innjoo Time2 10.1'' - 16GB - 3G - Preto 89,99 € 64,99 €
# 7. Tablet Huawei MediaPad T5 10.1'' - 64GB - Preto 279,99 € 199,99 €
# 8. Tablet Huawei MediaPad M5 Lite 10.1'' - 64GB 319,99 €
# 7. Tablet Samsung T510 Galaxy Tab A 10.1'' Wi-Fi - 32GB - Preto 219,99 € 159,99 €
# 7. Tablet Alcatel 1T 7.0'' - 8GB - Wi-Fi - Premium Black 69,99 € 44,99 €
# 7. Tablet Huawei MediaPad T5 10.1'' - 32GB 249,99 € 169,99 €
# 7. Tablet Samsung T290 Galaxy Tab A 2019 8.0'' Wi-Fi - 32GB - Preto 169,99 € 129,99 €
# 7. Apple iPad - 32GB Wi-Fi - Cinzento Sideral 369 € 295 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Cinzento Sideral 2019 499 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 64GB - Cinzento Sideral 2019 579 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Dourado 2019 499 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Prateado 2019 499 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Prateado 2019 399 € 349 €
# 8. Novo iPad Apple 10.2'' Wi-Fi + Cellular - 128GB - Cinzento Sideral 2019 639 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 256GB - Cinzento Sideral 2019 749 €
# 7. Tablet Samsung T510 Galaxy Tab A 10.1'' Wi-Fi - 32GB - Preto 219,99 € 159,99 €
# 7. Tablet Samsung T290 Galaxy Tab A 2019 8.0'' Wi-Fi - 32GB - Preto 169,99 € 129,99 €
# 7. Tablet Samsung T590 Galaxy Tab A 10.5 Wi-Fi - 32GB - Preto 299,99 € 219,99 €
# 7. Tablet Samsung T290 Galaxy Tab A 2019 8.0'' Wi-Fi - 32GB - Cinzento 169,99 € 129,99 €
# 7. Tablet Samsung Galaxy Tab S6 10.5'' - T860 - Wi-Fi - 128GB - Rose Blush 749,99 € 649,99 €
# 7. Tablet Samsung T510 Galaxy Tab A 10.1'' Wi-Fi - 32GB - Prateado 219,99 € 159,99 €
# 7. Tablet Samsung T590 Galaxy Tab A 10.5 Wi-Fi - 32GB - Cinzento 299,99 € 219,99 €
# 8. Tablet Samsung Galaxy Tab S6 10.5'' - T860 - Wi-Fi - 256GB - Mountain Gray 669,99 €
# 8. Tablet Samsung Galaxy Tab S5e 10.5'' - T720 - Wi-Fi - 64GB - Preto 364,94 €
# 8. Tablet Samsung Galaxy Tab S5e 10.5'' - T720 - Wi-Fi - 128GB - Prateado 449,99 €
# 8. Tablet Innjoo F702 7'' - 16GB - Preto 59,99 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Cinzento Sideral 2019 399 € 349 €
# 7. Apple iPad - 32GB Wi-Fi - Cinzento Sideral 369 € 295 €
# 7. Tablet Huawei MediaPad T5 10.1'' - 32GB 249,99 € 169,99 €
# 8. Novo iPad Apple 10.2'' Wi-Fi - 128GB - Cinzento Sideral 2019 499 €
# 8. Apple iPad Pro 12.9'' - 256GB WiFi - Cinzento Sideral 1 299 €
# 7. Novo iPad Apple 10.2'' Wi-Fi - 32GB - Dourado 2019 399 € 349 €
# 8. Apple iPad Pro 11'' - 256GB WiFi - Cinzento Sideral 1 079 €
# 8. Tablet Innjoo SuperB 10.1 3G - 32GB - Preto 119,99 €
# 8. Apple iPad Air 10.5'' Wi-Fi - 64GB - Cinzento Sideral 2019 579 €
# 7. Pokémon Sword - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Shield - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. FIFA 20 - PS4 - Jogo 69,99 € 49,99 €
# 8. Consola Nintendo Switch Neon 366,12 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Consola Sony PS4 Pro 1TB + Death Stranding Edição Especial 499,99 €
# 7. The Legend of Zelda: Breath of the Wild Nintendo Switch - Jogo 69,99 € 55,99 €
# 8. Consola Nintendo Switch Lite - 32GB - Amarelo 219,99 €
# 8. Consola Nintendo Switch Cinzento 366,82 €
# 8. Star Wars Jedi: Fallen Order - Deluxe Edition - PS4 - Jogo 91,64 €
# 8. Star Wars Jedi: Fallen Order - PS4 - Jogo 71,99 €
# 8. Death Stranding Special Edition - PS4 - Jogo 79,99 €
# 8. Death Stranding Collector's Edition - PS4 - Jogo 199,99 €
# 7. Need For Speed: Heat - PS4 - Jogo 69,99 € 50,99 €
# 7. Just Dance 2020 - PS4 - Jogo 49,99 € 39,99 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Medievil Remastered - PS4 - Jogo 29,99 €
# 7. Plants vs Zombies Battle for Neighborville - PS4 - Jogo 39,99 € 30,99 €
# 7. GRID - PS4 - Jogo 69,99 € 49,99 €
# 7. Zumba: Burn It Up - Nintendo Switch - Jogo 39,99 € 31,99 €
# 7. Pokémon Sword - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Shield - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Sword & Shield Dual Pack - Nintendo Switch - Jogo 119,99 € 95,99 €
# 7. Mario & Sonic at the Olympic Games Tokyo 2020 - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Just Dance 2020 - Nintendo Switch - Jogo 39,99 € 31,99 €
# 7. WRC 8 - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Ring Fit Adventure - Nintendo Switch - Jogo 79,99 € 63,99 €
# 7. The Witcher 3: Wild Hunt - Complete Edition - Nintendo Switch - Jogo 50,99 € 40,79 €
# 7. Dragon Quest XI: Echoes of an Elusive Age - Nintendo Switch - Jogo 59,99 € 47,99 €
# 8. Star Wars Jedi: Fallen Order - Xbox One - Jogo 71,99 €
# 7. Need For Speed: Heat - Xbox One - Jogo 69,99 € 50,99 €
# 7. Just Dance 2020 - Xbox One - Jogo 49,99 € 39,99 €
# 7. Plants vs Zombies Battle for Neighborville - Xbox One - Jogo 39,99 € 30,99 €
# 7. GRID - Xbox One - Jogo 69,99 € 49,99 €
# 8. Indivisible - Xbox One - Jogo 39,99 €
# 8. GRID - Ultimate Edition - Xbox One - Jogo 89,99 €
# 7. Tom Clancy’s Ghost Recon Breakpoint - Xbox One - Jogo 69,99 € 34,99 €
# 7. Tom Clancy’s Ghost Recon Breakpoint - Ultimate Edition - Xbox One - Jogo 119,99 € 59,99 €
# 7. Tom Clancy’s Ghost Recon: Breakpoint - Gold Edition - Xbox One - Jogo 99,99 € 49,99 €
# 7. The Last of Us 2 Standard - Capa Reversível - PS4 - Jogo 69,99 € 59,49 €
# 8. The Last of Us 2 Edição Colecionador - PS4 - Jogo 179,99 €
# 8. The Last of Us 2 Edição Especial - PS4 - Jogo 89,99 €
# 7. Doom Eternal - Collector's Edition - PS4 - Jogo 224,99 € 191,24 €
# 7. Doom Eternal - Deluxe Edition - PS4 - Jogo 99,99 € 84,99 €
# 7. Marvel's Avengers - PS4 - Jogo 69,99 € 59,49 €
# 7. Cyberpunk 2077 - Collector's Edition - PS4 - Jogo 229,99 € 195,49 €
# 7. Watch Dogs: Legion - Resistance Edition - PS4 - Jogo 69,99 € 59,49 €
# 7. Elden Ring - PS4 - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - PS4 - Jogo 69,99 € 59,49 €
# 7. Assassin’s Creed: The Rebel Collection - Nintendo Switch - Jogo 49,99 € 42,49 €
# 7. Animal Crossing - Nintendo Switch - Jogo 59,99 € 50,99 €
# 7. Gods & Monsters - Nintendo Switch - Jogo 69,99 € 59,49 €
# 7. Bayonetta 3 - Nintendo Switch - Jogo 69,99 € 59,49 €
# 7. Doom Eternal - Xbox One - Jogo 69,99 € 59,49 €
# 7. Elden Ring - Xbox One - Jogo 69,99 € 59,49 €
# 7. Marvel's Avengers - Xbox One - Jogo 69,99 € 59,49 €
# 7. Cyberpunk 2077 - Collector's Edition - Xbox One - Jogo 229,99 € 195,49 €
# 7. Watch Dogs: Legion - Resistance Edition - Xbox One - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - Xbox One - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - Gold Edition - Xbox One - Jogo 99,99 € 84,99 €
# 7. Watch Dogs: Legion - Ultimate Edition - Xbox One - Jogo 119,99 € 101,99 €
# 7. Gods & Monsters - Xbox One - Jogo 69,99 € 59,49 €
# 7. Halo Infinite - Xbox One - Jogo 70 € 59,50 €
# 7. FIFA 20 - PS4 - Jogo 69,99 € 49,99 €
# 7. Red Dead Redemption 2 PS4 - Jogo 64,99 € 29,99 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Crash Team Racing Nitro-Fueled - PS4 - Jogo 49,99 €
# 7. The Legend of Zelda: Breath of the Wild Nintendo Switch - Jogo 69,99 € 55,99 €
# 8. Call Of Duty: Modern Warfare Steelbook - PS4 - Jogo 5 €
# 7. Marvel Spider-Man PS4 - Jogo 39,99 € 19,99 €
# 8. Saber é Poder Playlink PS4 - Jogo 22,99 €
# 7. Knack 2 PS4 - Jogo 37 € 9,99 €
# 8. God of War - Playstation Hits - PS4 - Jogo 24,99 €
# 8. Comando Sony Dualshock 4 Steel Black PS4 64,90 €
# 8. Comando Sony DualShock 4 V2 Black + Fortnite 51,60 €
# 7. Auscultadores Gaming Razer Kraken X Multi-Plataformas 59,99 € 49,99 €
# 7. Comando Dualshock 4 Sunset Orange - PS4 143,98 € 120,99 €
# 8. Comando Sony Dualshock 4 - Rose Gold 50,84 €
# 8. Sony Comando DualShock 4 V2 Glacier White PS4 56,82 €
# 8. Sony Comando DualShock 4 V2 Magma Red PS4 51,60 €
# 8. Sony PS4 Dualshock 4 Crystal 69,99 €
# 8. Sony Comando DualShock 4 V2 Gold PS4 66,84 €
# 8. Sony Comando Dualshock 4 Red Camouflage PS4 51,60 €
# 8. Consola Sony PS4 Pro 1TB + Death Stranding Edição Especial 499,99 €
# 7. Consola Sony PS4 Slim 1TB + Horizon Zero Dawn + God Of War + The Last Of Us 349,99 € 249 €
# 8. Consola Nintendo Switch Neon 366,12 €
# 8. Consola Sony PS4 Pro 1TB + Fifa 20 429,99 €
# 8. Consola Sony PS4 Slim - 500GB + Voucher Fortnite 229 €
# 8. Consola Sony PS4 Pro - 1TB + Voucher Fortnite 338 €
# 8. Consola Nintendo Switch Lite - 32GB - Turquesa 198,99 €
# 7. Consola Sony PS4 Slim 1TB + Death Stranding 349,99 € 249 €
# 8. Consola Nintendo Switch Cinzento 366,82 €
# 8. Consola Nintendo Switch Lite - 32GB - Amarelo 219,99 €
# 7. Pokémon Sword - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Shield - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. FIFA 20 - PS4 - Jogo 69,99 € 49,99 €
# 8. Consola Nintendo Switch Neon 366,12 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Consola Sony PS4 Pro 1TB + Death Stranding Edição Especial 499,99 €
# 7. The Legend of Zelda: Breath of the Wild Nintendo Switch - Jogo 69,99 € 55,99 €
# 8. Consola Nintendo Switch Lite - 32GB - Amarelo 219,99 €
# 8. Consola Nintendo Switch Cinzento 366,82 €
# 8. Star Wars Jedi: Fallen Order - Deluxe Edition - PS4 - Jogo 91,64 €
# 8. Star Wars Jedi: Fallen Order - PS4 - Jogo 71,99 €
# 8. Death Stranding Special Edition - PS4 - Jogo 79,99 €
# 8. Death Stranding Collector's Edition - PS4 - Jogo 199,99 €
# 7. Need For Speed: Heat - PS4 - Jogo 69,99 € 50,99 €
# 7. Just Dance 2020 - PS4 - Jogo 49,99 € 39,99 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Medievil Remastered - PS4 - Jogo 29,99 €
# 7. Plants vs Zombies Battle for Neighborville - PS4 - Jogo 39,99 € 30,99 €
# 7. GRID - PS4 - Jogo 69,99 € 49,99 €
# 7. Zumba: Burn It Up - Nintendo Switch - Jogo 39,99 € 31,99 €
# 7. Pokémon Sword - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Shield - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Pokémon Sword & Shield Dual Pack - Nintendo Switch - Jogo 119,99 € 95,99 €
# 7. Mario & Sonic at the Olympic Games Tokyo 2020 - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Just Dance 2020 - Nintendo Switch - Jogo 39,99 € 31,99 €
# 7. WRC 8 - Nintendo Switch - Jogo 59,99 € 47,99 €
# 7. Ring Fit Adventure - Nintendo Switch - Jogo 79,99 € 63,99 €
# 7. The Witcher 3: Wild Hunt - Complete Edition - Nintendo Switch - Jogo 50,99 € 40,79 €
# 7. Dragon Quest XI: Echoes of an Elusive Age - Nintendo Switch - Jogo 59,99 € 47,99 €
# 8. Star Wars Jedi: Fallen Order - Xbox One - Jogo 71,99 €
# 7. Need For Speed: Heat - Xbox One - Jogo 69,99 € 50,99 €
# 7. Just Dance 2020 - Xbox One - Jogo 49,99 € 39,99 €
# 7. Plants vs Zombies Battle for Neighborville - Xbox One - Jogo 39,99 € 30,99 €
# 7. GRID - Xbox One - Jogo 69,99 € 49,99 €
# 8. Indivisible - Xbox One - Jogo 39,99 €
# 8. GRID - Ultimate Edition - Xbox One - Jogo 89,99 €
# 7. Tom Clancy’s Ghost Recon Breakpoint - Xbox One - Jogo 69,99 € 34,99 €
# 7. Tom Clancy’s Ghost Recon Breakpoint - Ultimate Edition - Xbox One - Jogo 119,99 € 59,99 €
# 7. Tom Clancy’s Ghost Recon: Breakpoint - Gold Edition - Xbox One - Jogo 99,99 € 49,99 €
# 7. The Last of Us 2 Standard - Capa Reversível - PS4 - Jogo 69,99 € 59,49 €
# 8. The Last of Us 2 Edição Colecionador - PS4 - Jogo 179,99 €
# 8. The Last of Us 2 Edição Especial - PS4 - Jogo 89,99 €
# 7. Doom Eternal - Collector's Edition - PS4 - Jogo 224,99 € 191,24 €
# 7. Doom Eternal - Deluxe Edition - PS4 - Jogo 99,99 € 84,99 €
# 7. Marvel's Avengers - PS4 - Jogo 69,99 € 59,49 €
# 7. Cyberpunk 2077 - Collector's Edition - PS4 - Jogo 229,99 € 195,49 €
# 7. Watch Dogs: Legion - Resistance Edition - PS4 - Jogo 69,99 € 59,49 €
# 7. Elden Ring - PS4 - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - PS4 - Jogo 69,99 € 59,49 €
# 7. Assassin’s Creed: The Rebel Collection - Nintendo Switch - Jogo 49,99 € 42,49 €
# 7. Animal Crossing - Nintendo Switch - Jogo 59,99 € 50,99 €
# 7. Gods & Monsters - Nintendo Switch - Jogo 69,99 € 59,49 €
# 7. Bayonetta 3 - Nintendo Switch - Jogo 69,99 € 59,49 €
# 7. Doom Eternal - Xbox One - Jogo 69,99 € 59,49 €
# 7. Elden Ring - Xbox One - Jogo 69,99 € 59,49 €
# 7. Marvel's Avengers - Xbox One - Jogo 69,99 € 59,49 €
# 7. Cyberpunk 2077 - Collector's Edition - Xbox One - Jogo 229,99 € 195,49 €
# 7. Watch Dogs: Legion - Resistance Edition - Xbox One - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - Xbox One - Jogo 69,99 € 59,49 €
# 7. Watch Dogs: Legion - Gold Edition - Xbox One - Jogo 99,99 € 84,99 €
# 7. Watch Dogs: Legion - Ultimate Edition - Xbox One - Jogo 119,99 € 101,99 €
# 7. Gods & Monsters - Xbox One - Jogo 69,99 € 59,49 €
# 7. Halo Infinite - Xbox One - Jogo 70 € 59,50 €
# 7. FIFA 20 - PS4 - Jogo 69,99 € 49,99 €
# 7. Red Dead Redemption 2 PS4 - Jogo 64,99 € 29,99 €
# 7. Call Of Duty Modern Warfare Remastered - PS4 - Jogo 69,99 € 49,99 €
# 8. Crash Team Racing Nitro-Fueled - PS4 - Jogo 49,99 €
# 7. The Legend of Zelda: Breath of the Wild Nintendo Switch - Jogo 69,99 € 55,99 €
# 8. Call Of Duty: Modern Warfare Steelbook - PS4 - Jogo 5 €
# 7. Marvel Spider-Man PS4 - Jogo 39,99 € 19,99 €
# 8. Saber é Poder Playlink PS4 - Jogo 22,99 €
# 7. Knack 2 PS4 - Jogo 37 € 9,99 €
# 8. God of War - Playstation Hits - PS4 - Jogo 24,99 €
# 8. Comando Sony Dualshock 4 Steel Black PS4 64,90 €
# 8. Comando Sony DualShock 4 V2 Black + Fortnite 51,60 €
# 7. Auscultadores Gaming Razer Kraken X Multi-Plataformas 59,99 € 49,99 €
# 7. Comando Dualshock 4 Sunset Orange - PS4 143,98 € 120,99 €
# 8. Comando Sony Dualshock 4 - Rose Gold 50,84 €
# 8. Sony Comando DualShock 4 V2 Glacier White PS4 56,82 €
# 8. Sony Comando DualShock 4 V2 Magma Red PS4 51,60 €
# 8. Sony PS4 Dualshock 4 Crystal 69,99 €
# 8. Sony Comando DualShock 4 V2 Gold PS4 66,84 €
# 8. Sony Comando Dualshock 4 Red Camouflage PS4 51,60 €
# 8. Consola Sony PS4 Pro 1TB + Death Stranding Edição Especial 499,99 €
# 7. Consola Sony PS4 Slim 1TB + Horizon Zero Dawn + God Of War + The Last Of Us 349,99 € 249 €
# 8. Consola Nintendo Switch Neon 366,12 €
# 8. Consola Sony PS4 Pro 1TB + Fifa 20 429,99 €
# 8. Consola Sony PS4 Slim - 500GB + Voucher Fortnite 229 €
# 8. Consola Sony PS4 Pro - 1TB + Voucher Fortnite 338 €
# 8. Consola Nintendo Switch Lite - 32GB - Turquesa 198,99 €
# 7. Consola Sony PS4 Slim 1TB + Death Stranding 349,99 € 249 €
# 8. Consola Nintendo Switch Cinzento 366,82 €
# 8. Consola Nintendo Switch Lite - 32GB - Amarelo 219,99 €

# %% [markdown]
# # Worten Product Prices

# %%
def extract_prices_worten(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    price_container = soup.find("div", class_="w-product-general_info")
    if price_container:
        old_price_tag = price_container.find("span", class_="w-product__price__old")
        current_price_tag = price_container.find("span", class_="w-product__price__current")
        
        old_price = old_price_tag.get_text(strip=True) if old_price_tag else None
        current_price = current_price_tag.get_text(strip=True) if current_price_tag else None
        
        if current_price:
            print('1.', old_price, current_price)
            return {'old_price': old_price, 'current_price': current_price}

    price_container_box = soup.find("div", class_="w-product__price")
    if price_container_box:
        old_price_tag = price_container_box.find("span", class_="w-product__price__old")
        current_price_tag = price_container_box.find("span", class_="w-product__price__current")
        
        old_price = old_price_tag.get_text(strip=True) if old_price_tag else None
        current_price = current_price_tag.get_text(strip=True) if current_price_tag else None
        
        if current_price:
            print('2.', old_price, current_price)
            return {'old_price': old_price, 'current_price': current_price}

    price_box = soup.find("div", class_="price-box")
    if price_box:
        old_price_tag = price_box.find("p", class_="old-price")
        special_price_tag = price_box.find("p", class_="special-price")
        regular_price_tag = price_box.find("p", class_="regular-price")
        
        if old_price_tag and special_price_tag:
            old_price = old_price_tag.find("span", class_="price").get_text(strip=True)
            current_price = special_price_tag.find("span", class_="price").get_text(strip=True)
            print('3.', old_price, current_price)
            return {'old_price': old_price, 'current_price': current_price}
        
        elif regular_price_tag:
            current_price = regular_price_tag.find("span", class_="price").get_text(strip=True)
            print('4.', current_price)
            return {'current_price': current_price}
        
    products_container = soup.find_all("div", class_="w-product__content")
    if products_container:
        products = []
        for product in products_container:
            name_tag = product.find("div", class_="w-product__title__wrapper")
            price_tag = product.find("span", class_="w-currentPrice")
            
            product_name = name_tag.get_text(strip=True) if name_tag else None
            current_price = price_tag.get_text(strip=True) if price_tag else None
            
            if product_name and current_price:
                print('5.', product_name, current_price)
                products.append({
                    'product_name': product_name,
                    'current_price': current_price
                })
        
        return products if products else None


    return None


def process_row_worten(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.worten.pt':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
                continue
            
            extracted_data = extract_prices_worten(text, site)
            
            if extracted_data:
                if isinstance(extracted_data, list):
                    for product in extracted_data:
                        old = product['old_price'] if 'old_price' in product else None
                        current = product['current_price'] if 'current_price' in product else None
                        price = [current, old] if old and current else [current]
                        titulo = product['product_name'] if 'product_name' in product else None
                        extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': titulo,
                            'extractedData': price,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
                else:
                    old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                    current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                    price = [current, old] if old and current else [current]
                    
                    extracted_data_list.append({
                        'site': site,
                        'date': date,
                        'title': title,
                        'extractedData': price,
                        'linkToArchive': link,
                        'linkToExtractedText': row['linkToExtractedText'],
                        'snippet': snippet
                    })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')        
result_list = process_row_worten(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_WORTEN.csv', index=False)
# Out:
# Error while fetching https://arquivo.pt/wayback/20160221001735mp_/https://www.worten.pt/smartphone-huawei-p8-lite-dourado.html
# 2. €229,99 €199,99
# 2. €699,99 €579,99
# 2. €699,99 €579,99
# 2. €999,99 €849,99
# 2. €1049,00 €899,99
# 2. €1049,00 €899,99
# 2. €719,99 €585,99
# 2. €719,99 €599,99
# 2. None €969,99
# 2. None €869,99
# 2. €909,00 €599,99
# 2. €909,00 €599,99
# Error while fetching https://arquivo.pt/wayback/20151209031224mp_/https://www.worten.pt/iphone-6-apple-64gb-space-grey.html
# 2. None €829,99
# 2. None €829,99
# 2. None €1179,00
# 2. None €1359,00
# 2. None €879,99
# 2. None €1349,00
# 2. None €1349,00
# 2. None €1179,00
# 2. None €879,99
# 2. None €1049,00
# 2. None €379,99
# 5. Consola PS4 Pro 1 TB + Jogo Red Dead Redemption 2 €439,99
# 5. Consola PS4 Slim 500 GB + Jogo Fortnite €299,99
# 5. Consola PS4 Pro 1 TB + Voucher Jogo Fortnite €399,99
# 5. Consola PS4 Slim 1TB Marvel's Spider-Man (Edição Limitada) €379,99
# 5. Consola PS4 Red Dead Redemption 2 €349,99
# 5. Consola PS4 Slim 1TB + Jogo Marvel's Spider-Man €349,99
# 5. Consola PS4 Slim 1TB (Edição Especial) + Jogo Gran Turismo Sport Edição Plus €379,99
# 5. Consola PS4 Slim 500GB Preta €299,99
# 5. Consola PS4 Pro 1TB Preta €399,99
# 5. Consola PS4 Slim 500GB Preta €323,16
# 5. Consola 1TB Pro + Kingdom Hearts III €469,99
# 5. Consola PS4 Slim 500 GB + Jogo Fortnite €376,09
# 5. Consola PS4 Slim 1TB Preta + 2 Comandos Dualshock 4 €349,99
# 5. Consola PS4 Slim 500 GB Days of Play €598,00
# 5. Consola PS4 Slim + FIFA 21 (500 GB) €339,99
# 5. Consola PS4 Slim + Horizon Zero Dawn + Ratchet & Clank + Spider-man (500 GB) €339,99
# 5. Consola PS4 Pro + FIFA 21 (1 TB) €369,99
# 5. Consola PS4 Pro (1 TB) €401,10
# 5. Consola PS4 Slim (500 GB) €325,00
# 5. Consola PS4 Pro + FIFA 20 (1 TB) €369,99
# 5. Consola PS4 Pro Playstation HITS (1 TB) €499,99
# 5. Consola PS4 Pro (1 TB) €539,79
# 5. Consola PS4 Slim + FIFA 20 + Voucher (1 TB) €560,90
# 5. Consola PS4 Pro + The Last of Us Parte II (1 TB) €599,99
# 5. Consola PS4 Pro + Fortnite + Voucher (1 TB) €579,99
# 5. Consola PS4 Slim + FIFA 20 + Voucher (500 GB) €620,99
# 5. Consola PS4 Pro 500M (Edição Limitada - 2 TB) €2298,85
# 5. Consola PS4 Slim + Fortnite + Voucher (500 GB) €492,20
# 5. Consola PS4 Standard + GTA V (500 GB) €620,99
# 5. Consola PS4 Slim + Horizon Zero Dawn + The Last of Us + Uncharted 4 (1 TB) €620,99
# 5. Consola PS4 Pro Kingdom Hearts III (Limited Edition - 1 TB) €699,90
# 5. Consola PS4 Slim + Voucher Fortnite (500 GB) €562,35
# 5. Consola PS4 Pro (1 TB) €747,49
# 5. Consola PS4 Slim + FIFA 19 (1 TB) €574,99
# 5. Consola PS4 Slim + FIFA 20 + Voucher (1 TB) €632,49
# 5. Consola PS4 Slim +  The Last of Us + Horizon Zero Dawn + Uncharted  (1 TB) €620,99
# 5. Consola PS4 Slim + Uncharted 4 (1 TB) €499,00
# 5. Consola PS4 Standard + Knack (500 GB) €517,49
# 5. Consola PS4 Slim + FIFA 21 (500 GB) €339,99
# 5. Consola PS4 Slim + Horizon Zero Dawn + Ratchet & Clank + Spider-man (500 GB) €339,99
# 5. Consola PS4 Pro + FIFA 21 (1 TB) €369,99
# 5. Consola PS4 Pro (1 TB) €401,10
# 5. Consola PS4 Slim (500 GB) €325,00
# 5. Consola PS4 Pro + FIFA 20 (1 TB) €369,99
# 5. Consola PS4 Pro Playstation HITS (1 TB) €499,99
# 5. Consola PS4 Pro (1 TB) €539,79
# 5. Consola PS4 Slim + FIFA 20 + Voucher (1 TB) €560,90
# 5. Consola PS4 Pro + The Last of Us Parte II (1 TB) €599,99
# 5. Consola PS4 Pro + Fortnite + Voucher (1 TB) €579,99
# 5. Consola PS4 Slim + FIFA 20 + Voucher (500 GB) €620,99
# 5. Consola PS4 Pro 500M (Edição Limitada - 2 TB) €2298,85
# 5. Consola PS4 Slim + Fortnite + Voucher (500 GB) €492,20
# 5. Consola PS4 Standard + GTA V (500 GB) €620,99
# 5. Consola PS4 Slim + Horizon Zero Dawn + The Last of Us + Uncharted 4 (1 TB) €620,99
# 5. Consola PS4 Pro Kingdom Hearts III (Limited Edition - 1 TB) €699,90
# 5. Consola PS4 Slim + Voucher Fortnite (500 GB) €562,35
# 5. Consola PS4 Pro (1 TB) €747,49
# 5. Consola PS4 Slim + FIFA 19 (1 TB) €574,99
# 5. Consola PS4 Slim + FIFA 20 + Voucher (1 TB) €632,49
# 5. Consola PS4 Slim +  The Last of Us + Horizon Zero Dawn + Uncharted  (1 TB) €620,99
# 5. Consola PS4 Slim + Uncharted 4 (1 TB) €499,00
# 5. Consola PS4 Standard + Knack (500 GB) €517,49
# 4. €49,99
# 4. €49,99
# 5. Consola Xbox One S Star Wars Jedi: Fallen Order (1 TB - Branco) €150,00
# 5. Consola XBOX ONE S + 2º comando (1 TB - Branco) €362,50
# 5. Consola Xbox One S + Jogo Gears of War 5 (1 TB + Branco) €150,00
# 5. Consola XBOX ONE S Forza Horizon 4 (1 TB - Branco) €289,99
# 5. Consola Xbox One S + Jogo Tom Clancy's The Division 2 (1 TB - M18) €150,00
# 5. Consola Xbox One S Forza Horizon 4: Lego (1 TB - Branco) €150,00
# 5. Consola Xbox One S Game Pass 3 M (1 TB - Branco) €327,62
# 5. Consola XBOX ONE S 1 TB + Jogo Anthem (M16) €150,00
# 5. Consola Xbox One S GreyJoy Battlefield V (1 TB - Branco) €150,00
# 5. Consola XBOX ONE S Fortnite (1 TB - Branco) €302,20
# 5. Consola Xbox One S 1TB Roxa + Fortnite Battle Royale Special Edition €440,77
# 5. Consola Xbox One S Playerunknowns Battleground (1 TB - Branco) €227,85
# 5. Consola XBOX ONE S Minecraft Story Mode (500 GB - Branco) €377,11
# 5. Consola XBOX ONE S FIFA 17 (500 GB - Branco) €368,56
# 5. Consola XBOX ONE S Minecraft (1 TB - Branco) €404,69
# 5. Consola Xbox One S Minecraft Master Creators (1 TB - Branco) €347,74
# 5. Consola XBOX ONE S 1TB All Digital Edition (M12) €229,99
# 5. Consola Xbox One X + Jogo Gears of War 5 (1 TB + Preto) €499,99
# 5. Consola XBOX ONE X + Jogo Fall Out (1 TB - Branco) €420,91
# 5. Consola XBOX ONE X Lannister Battlefield (1 TB - Preto) €499,99
# 5. Consola XBOX ONE X Metro Exodus (1 TB - Preto) €499,99
# 5. Consola XBOX ONE X + Tom Clancy's The Division 2 (1TB - M18) €499,99
# 5. Consola Xbox One X Star Wars Jedi: Fallen Order (1 TB - Preto) €499,99
# 5. Consola XBOX ONE X Forza Horizon 4 + Motorsport 7 (1 TB - Preto) €727,87
# 2. None €249,99
# 2. None €109,99
# 2. None €89,99
# 5. Consola Xbox One S (1 TB) €249,99
# 5. Consola Xbox One S GreyJoy Battlefield V  (1 TB) €249,99
# 5. Consola Xbox One S + Gears of War 5  (1 TB) €374,40
# 5. Consola Xbox One X + Fall Out  (1 TB) €399,99
# 5. Consola Xbox One S + 2º comando (1 TB - Branco) €445,99
# 5. Consola Xbox One X Cyberpunk 2077  (1 TB) €773,41
# 5. Consola Xbox One S All Digital Edition  (1 TB) €273,20
# 5. Consola Xbox One X (1 TB - Preto) €648,69
# 5. Consola Xbox One X + Tom Clancy's The Division 2  (1 TB) €954,62
# 5. Consola Xbox One X Gears Of War 5  (1 TB) €599,90
# 5. Consola Xbox One S Fortnite  (1 TB) €302,20
# 5. Consola XBOX ONE S FIFA 17 (1 TB - Branco) €565,95
# 5. Consola Xbox One S + Tom Clancy's The Division 2  (1 TB) €328,62
# 5. Consola XBOX ONE S Battlefield (500 GB - Branco) €808,24
# 5. Consola MICROSOFT Xbox One S 1TB + Comando Wireless + Xbox Live Gold 14G €478,66
# 5. Consola Xbox One S (1 TB) €249,99
# 5. Consola Xbox One S GreyJoy Battlefield V  (1 TB) €249,99
# 5. Consola Xbox One S + Gears of War 5  (1 TB) €374,40
# 5. Consola Xbox One X + Fall Out  (1 TB) €399,99
# 5. Consola Xbox One S + 2º comando (1 TB - Branco) €374,89
# 5. Consola Xbox One X Cyberpunk 2077  (1 TB) €773,41
# 5. Consola Xbox One S All Digital Edition  (1 TB) €273,20
# 5. Consola Xbox One X (1 TB - Preto) €623,69
# 5. Consola Xbox One X + Tom Clancy's The Division 2  (1 TB) €782,66
# 5. Consola Xbox One S Fortnite  (1 TB) €302,20
# 5. Consola Xbox One X Gears Of War 5  (1 TB) €599,90
# 5. Consola Xbox One S + Tom Clancy's The Division 2  (1 TB) €328,62
# 5. Consola Xbox Series X (1 TB) €499,00

# %%
df = pd.read_csv('data/resultados_black_friday_arquivo.csv')
result_list = process_row_worten(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_WORTEN_Black_Friday.csv', index=False)
# Out:
# 5. Recondicionado - Smartphone iPhone 6 16GB Cinzento sideral €179,99
# 5. Recondicionado - Smartphone iPhone 8 64GB Dourado €579,99
# 5. Recondicionado - Smartphone iPhone 6 64GB Prateado €259,99
# 5. Recondicionado - Smartphone iPhone 6 64GB Cinzento sideral €259,99
# 5. Recondicionado - Smartphone iPhone 7 128GB Prateado €449,99
# 5. Recondicionado - Smartphone iPhone SE 16GB Rosa Dourado €199,99
# 5. Recondicionado - Smartphone iPhone 6 64GB Dourado €259,99
# 5. Recondicionado - Smartphone iPhone 7 32GB Preto €379,99
# 5. Recondicionado - Smartphone iPhone 6s 32GB Cinzento sideral €289,99
# 5. Recondicionado - Smartphone iPhone 6s 16GB Rosa Dourado €249,99
# 5. Recondicionado - Smartphone iPhone SE 16GB Prateado €199,99
# 5. Recondicionado - Smartphone Samsung Galaxy S7 Edge 32GB Rosa €379,99
# 5. Recondicionado - Smartphone iPhone 6s 16GB Cinzento Sideral €249,99
# 5. Recondicionado - Smartphone Samsung Galaxy S7 Edge 32GB Dourado €379,99
# 5. Recondicionado - Smartphone iPhone SE 16GB Dourado €199,99
# 5. Recondicionado - Coluna Hi-Fi NAIM Muso QB €499,99
# 5. Recondicionado - Smartphone iPhone 6s 16GB Prateado €249,99
# 5. Recondicionado - Smartphone iPhone 6s 64GB Dourado €319,99
# 5. Recondicionado - Smartphone Samsung Galaxy S7 32GB Prateado €299,99
# 5. Recondicionado - Smartphone iPhone 7 128GB Preto €449,99
# 5. Recondicionado - Smartphone Samsung Galaxy S8 64GB Dourado €449,99
# 5. Recondicionado - Smartphone Samsung Galaxy S8 64GB Preto €449,99
# 5. Recondicionado - Smartphone Samsung Galaxy S7 32GB Preto €299,99
# 5. Recondicionado - Smartphone iPhone 7 Plus 128GB Preto €559,99
# 5. iPad 9.7'' APPLE Wi-Fi 32 GB Cinzento Sideral €312,70
# 5. Cartão Memória MicroSDHC SANDISK 64GB Ultra A1 100MB/s €12,99
# 5. Disco Externo HDD 2.5'' TOSHIBA USB 3.0 Canvio Basic 2 TB €64,00
# 5. Disco Externo 2,5'' SEAGATE Expansion Portable 4TB €89,00
# 5. Monitor LED 24'' HP 24O 1ms €89,00
# 5. iPad 9.7'' APPLE Wi-Fi 32 GB Prateado €297,00
# 5. Tablet 10.1'' SAMSUNG TAB A 32 GB Cinzento €176,00
# 5. iPad 9.7'' APPLE Wi-Fi 32 GB Dourado €315,65
# 5. Tablet 7'' ALCATEL 1T 8GB €44,00
# 5. Disco Externo HDD 2.5'' TOSHIBA USB 3.0 Canvio Basic 1 TB €49,00
# 5. Pack Portátil HP 14'' 14-CB055NP €299,99
# 5. Monitor Gaming LED 24'' AOC C24G1 €300,00
# 5. Monitor LED IPS 24'' HP 24F €119,99
# 5. Portátil 14'' LENOVO Yoga 530-14IKB €799,99
# 5. Cartão Memória MicroSDHC SANDISK 128GB Ultra A1 100MB/s €19,99
# 5. Impressora Foto HP Sprocket €74,99
# 5. Pen USB PNY 128GB ATTACHE4 2.0 €18,99
# 5. Tablet 10.8'' HUAWEI M5 32GB Wi-Fi Cinzento €299,99
# 5. Rato Gaming RAZER Deathadder Elite €86,32
# 5. Disco Externo WD 2.5'' ELEMENTS 1TB USB 3.0 €69,99
# 5. Pen USB PNY 64GB Attaché4 €9,99
# 5. Disco Externo SEAGATE Backup Plus HUB 6TB €119,99
# 5. Portátil 15.6'' LENOVO IdeaPad 330-15IKB-182 €499,99
# 5. Portátil Gaming 15.6'' LENOVO Legion Y530-15ICH-196 €999,00
# 2. None €149,00
# 2. None €149,00
# 5. Cadeira Gaming SPARCO Stint em Preto e Vermelho €354,99
# Error while fetching https://arquivo.pt/wayback/20181123182944mp_/https://www.worten.pt/gaming/ps4/consolas-ps4
# 2. None €149,00
# 2. None €838,99
# 2. None €838,99
# 5. iPad APPLE 2019 Cinzento Sideral (10.2'' - 32 GB - Chip A10 Fusion) €346,00
# 5. iPad APPLE Cinzento Sideral - MR7F2TY/A (9.7'' - 32 GB - Chip A10 Fusion) €417,83
# 5. iPad Air APPLE 2019 Cinzento Sideral (10.5'' - 64 GB - Chip A12 Bionic) €604,99
# 5. iPad APPLE 2019 Dourado (10.2'' - 32 GB - Chip A10 Fusion) €399,99
# 5. iPad Air APPLE 2019 Cinzento Sideral - MUUQ2TY/A (10.5'' - 256 GB - Chip A12 Bionic) €682,49
# 5. iPad Pro APPLE 2018 Cinzento Sideral - MTXN2TY/A (11'' - 64 GB - Chip A12X Bionic) €909,99
# 5. iPad APPLE 2019 Cinzento Sideral (10.2'' - 128 GB - Chip A10 Fusion) €511,99
# 5. iPad Air APPLE 2019 Prateado - MUUR2TY/A (10.5'' - 256 GB - Chip A12 Bionic) €734,29
# 5. iPad Air APPLE 2019 Prateado - MUUK2TY/A (10.5'' - 64 GB - Chip A12 Bionic) €609,99
# 5. iPad Air APPLE 2019 Cinzento Sideral - MV0N2TY/A (10.5'' - 256 GB - Chip A12 Bionic - Wi-Fi + Cellular) €889,99
# 5. iPad mini APPLE 2019 Cinzento Sideral - MUX52TY/A (7.9'' - 64 GB - Chip A12 Bionic - Wi-Fi + Cellular) €561,19
# 5. iPad Pro APPLE 2018 Prateado - MTXP2TY/A (11'' - 64 GB - Chip A12X Bionic) €909,99
# 5. iPad APPLE 2019 Prateado (10.2'' - 32 GB - Chip A10 Fusion) €399,99
# 5. iPad mini APPLE 2019 Cinzento Sideral - MUXC2TY/A (7.9'' - 256 GB - Chip A12 Bionic - Wi-Fi + Cellular) €779,99
# 5. iPad Pro APPLE 2018 Cinzento Sideral - MTFL2TY/A (12.9'' - 256 GB - Chip A12X Bionic) €1299,00
# 5. iPad Pro APPLE 2018 Cinzento Sideral - MTEL2TY/A (12.9'' - 64 GB - Chip A12X Bionic - Wi-Fi + Cellular) €1182,67
# 5. iPad APPLE Cinzento Sideral - MR7J2TY/A (9.7'' - 128 GB - Chip A10 Fusion) €462,81
# 5. iPad Pro APPLE Rosa Dourado - MPGL2TY/A (10.5'' - 512 GB - Chip A10X Fusion) €975,99
# 5. iPad Air APPLE 2019 Cinzento Sideral - MV0D2TY/A (10.5'' - 64 GB - Chip A12 Bionic - Wi-Fi + Cellular) €719,99
# 5. iPad Air APPLE 2019 Dourado - MUUT2TY/A (10.5'' - 256 GB - Chip A12 Bionic) €682,49
# 5. iPad mini APPLE 2019 Prateado - MUQX2TY/A (7.9'' - 64 GB - Chip A12 Bionic) €501,43
# 5. iPad mini APPLE 2019 Dourado - MUQY2TY/A (7.9'' - 64 GB - Chip A12 Bionic) €506,02
# 5. iPad mini APPLE 2019 Cinzento Sideral - MUQW2TY/A (7.9'' - 64 GB - Chip A12 Bionic) €469,99
# 5. APPLE iPad (9.7'' - 32 GB - Prateado) €450,89
# 2. None €499,99
# 2. None €679,99
# 2. None €679,99
# 2. None €189,99
# 2. None €189,99
# 2. None €189,99
# 2. None €189,99
# 2. None €679,99
# 2. None €679,99
# 5. Máquina de Café KRUPS Nespresso Essenza XN1101P2 (19 bar - Branco) €29,99
# 5. Máquina de Café KRUPS Nespresso Essenza XN1108P2 (19 bar - Preto) €22,00
# 5. Máquina de Café KRUPS Nespresso Essenza Mini XN110B (19 bar - Cinzento) €59,99
# 5. Máquina de Café NESPRESSO Delonghi Inissia EN80.B (19 bar - Preto) €59,99
# 5. Máquina de Café de Cápsulas NESPRESSO DeLonghi Latissima One EN500.B (19 bar - Preto) €169,99
# 5. Máquina de Café DELTA Q Quick Branca (19 bar) €39,99
# 5. Máquina de Café DELTA Q Quick Vermelho (19 bar) €39,99
# 5. Máquina de Café NESPRESSO Delonghi Lattissima One EN500.W (19 bar - Branco) €169,99
# 5. Máquina de Café KRUPS Nespresso Inissia XN1005P04 (19 bar - Vermelho) €59,99
# 5. Máquina de Café DELONGHI Nespresso EN124S Pixie (19 bar - Inox) €69,99
# 5. Máquina de Café DOLCE GUSTO Krups KP123BP12 Mini Me + 60 Cápsulas (15 bar - Cinzento) €54,99
# 5. Máquina de Café KRUPS Dolce Gusto KP1A08P12 Piccolo XS (15 bar - Preto) €39,99
# 5. Máquina de Café KRUPS Nespresso Essenza Mini XN1118P2 & Aeroccino3 (19 bar - Preto) €89,99
# 5. Máquina de Café KRUPS Dolce Gusto KP3408P12 Genio S + 60 Cápsulas (15 bar - Preto) €74,99
# 5. Máquina de Café KRUPS Dolce Gusto KP1308P0 Lumio Preto €49,97
# 5. Máquina de Café DELTA Q Qool Evolution (19 bar - Preto) €79,99
# 5. Máquina de Café NESPRESSO Delonghi Essenza Mini EN85R (19 bar - Vermelho) €59,99
# 5. Máquina de Café DELONGHI Nespresso Essenza Mini EN85B (19 bar - Preto) €59,99
# 5. Máquina de Café NESPRESSO Delonghi Essenza Mini EN85L (19 bar - Verde) €59,99
# 5. Máquina de Café KRUPS Dolce Gusto Lumio KP1301P12 BR + 60 Cápsulas (15 bar - Branco) €69,99
# 5. Máquina de Café NESPRESSO Delonghi Expert EN350 G (19 bar - Cinzento) €219,99
# 5. Máquina de Café IKOHS Potts Preto €60,00
# 5. Máquina de Café DELTA Q Qool Evolution (19 bar - Vermelho) €79,99
# 5. Máquina de Café Delonghi NESPRESSO EN650B (19 bar - Preto) €269,99
# 5. Consola Portátil Nintendo Switch V2 (32 GB - Azul  e Vermelho Néon) €279,99
# 5. Consola Nintendo Switch Lite + Animal Crossing (32 GB - Turquesa) €229,00
# 5. iPhone SE APPLE (4.7'' - 128 GB - Preto) €449,99
# 5. Coluna Bluetooth JBL Xtreme 2 GM (40W - Autonomia 15 horas) €149,99
# 5. SAMSUNG Galaxy Watch 46mm Cinza €199,99
# 5. Comando PS4 Dualshock Black v2 (Wireless) €39,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 128 GB - Branco) €229,99
# 5. Máquina de Café KRUPS Nespresso Essenza XN1108P2 (19 bar - Preto) €22,00
# 5. TV LG 75UN85006 (LED - 75'' - 191 cm - 4K Ultra HD - Smart TV) €999,99
# 5. Monitor LG 29WL500-B (29'' - Full HD - LED IPS - FreeSync) €179,99
# 5. Tablet SAMSUNG Galaxy Tab S6 Lite (10.4'' - 64 GB - 4 GB RAM - Wi-Fi - Cinzento) €299,99
# 5. Desktop Gaming HP Pavilion TG01-1024np (Intel Core i5-10400F - NVIDIA GeForce GTX 1660 Super - RAM: 16 GB - 512 GB SSD PCIe) €749,99
# 5. Kit Máquina Fotográfica Reflex CANON EOS 2000D + 18-55 mm DC + Bolsa SB130 + 16 GB (24.1 MP - Sensor APS-C - ISO: 100 a 12800) €299,99
# 5. Purificador de Ar  AIRFREE P3000 ( 32 m2) €99,99
# 5. Consola PS4 Slim + FIFA 21 (500 GB) €299,99
# 5. Aspirador Vertical DYSON V8 Animal + (21.6 V - Autonomia: 40 min - 540 ml) €269,99
# 5. Máquina de Lavar Roupa SAMSUNG Addwash WW80T554DTW (8 kg - 1400 rpm - Branco) €379,99
# 5. Máquina de Lavar Loiça CANDY CDPN 2D360PW (13 Conjuntos - 60 cm - Branco) €279,99
# 5. Placa de Indução BECKEN BIH3300 (Elétrica - 59 cm - Preto) €199,99
# 5. Frigorífico Americano LG GSX961MCVZ Instaview (No Frost - 179 cm - 601 L - Preto) €1599,00
# 5. Cave de Vinho BECKEN BWC3989 (17 Garrafas - Inox) €149,99
# 5. Micro-ondas LG NeoChef MH6336GIB (23 L - Com Grill - Preto) €99,99
# 5. Máquina de Lavar Roupa  BEKO WTA 9712 XSWR (9 kg - 1400 rpm - Branco) €289,99
# 5. Máquina de Secar Roupa HOTPOINT NT M11 82SK EU (8kg - Bomba de Calor - Branco) €459,99
# 5. TV LG OLED55CX5 (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV) €1249,00
# 5. Robô de Cozinha MOULINEX ICompanion HF900110 (4.5 L - 1550 W - 5 acessórios) €399,99
# 5. Varinha BOSCH MSM67170 (750 W - 12 velocidades) €34,99
# 5. Auscultador Bluetooth PHILIPS TAPH805BK (Over Ear - Microfone - Noise Canceling) €89,99
# 5. Smartphone SAMSUNG Galaxy A20s (6.5'' - 3 GB - 32 GB - Preto) €129,99
# 5. Sistema Mesh TP-LINK Deco M4 2 Unid. (AC1200 - 300 + 867 Mbps) €69,99
# 5. Perfume CALVIN KLEIN Endless Euphoria Eau de Parfum (125 ml) €29,97
# 5. Trator a Pedal HOMCOM 341-018 (114 x 41 x 52 cm) €74,99
# 5. Smartphone SAMSUNG Galaxy A30s (6.4'' - 4 GB - 128 GB - Preto) €189,99
# 5. Smartphone SAMSUNG Galaxy S20 (6.2'' - 8 GB - 128 GB - Cinzento) €599,99
# 5. Smartphone SAMSUNG Galaxy A20s (6.5'' - 3 GB - 32 GB - Preto) €129,99
# 5. Smartphone SAMSUNG Galaxy A20e (5.8'' - 3 GB - 32 GB - Preto) €139,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 4 GB - 64 GB - Branco) €179,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 3 GB - 32 GB - Preto) €159,99
# 5. Smartphone SAMSUNG Galaxy A51 (6.5'' - 4 GB - 128 GB - Preto) €289,99
# 5. Smartphone SAMSUNG Galaxy A20s (6.5'' - 3 GB - 32 GB - Azul) €129,99
# 5. Smartphone SAMSUNG Galaxy A31 (6.4'' - 4 GB - 64 GB - Preto) €229,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 4 GB - 128 GB - Preto) €209,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 3 GB - 32 GB - Branco) €159,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 4 GB - 64 GB - Azul) €203,19
# 5. Smartphone SAMSUNG Galaxy A31 (6.4'' - 4 GB - 128 GB - Prateado) €249,99
# 5. Smartphone SAMSUNG Galaxy A30s (6.4'' - 4 GB - 128 GB - Branco) €189,99
# 5. Smartphone SAMSUNG Galaxy A20e (5.8'' - 3 GB - 32 GB - Azul) €139,99
# 5. Smartphone SAMSUNG Galaxy A31 (6.4'' - 4 GB - 128 GB - Preto) €249,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 4 GB - 128 GB - Branco) €209,99
# 5. Smartphone SAMSUNG Galaxy A21s (6.55'' - 3 GB - 32 GB - Azul) €159,99
# 5. Smartphone SAMSUNG Galaxy A20e (5.8'' - 3 GB - 32 GB - Coral) €139,99
# 5. Smartphone SAMSUNG Galaxy A31 (6.4'' - 4 GB - 64 GB - Prateado) €229,99
# 5. Smartphone SAMSUNG Galaxy A51 (6.5'' - 4 GB - 128 GB - Branco) €289,99
# 5. Smartphone SAMSUNG Galaxy S20+ 5G (6.7'' - 12 GB - 128 GB - Preto) €799,99
# 5. Smartphone SAMSUNG Galaxy A20e (5.8'' - 3 GB - 32 GB - Branco) €139,99
# 5. Smartphone SAMSUNG Galaxy S20 (6.2'' - 8 GB - 128 GB - Rosa) €599,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 128 GB - Cinzento) €229,99
# 5. Smartphone XIAOMI Redmi 9 (6.53'' - 4 GB - 64 GB - Roxo) €129,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 128 GB - Verde) €229,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 128 GB - Branco) €229,99
# 5. Smartphone XIAOMI Mi 10 Lite 5G (6.57'' - 6 GB - 128 GB - Azul) €279,99
# 5. Smartphone XIAOMI Redmi 9 (6.53'' - 4 GB - 64 GB - Cinzento) €139,69
# 5. Smartphone XIAOMI Redmi 9 (6.53'' - 4 GB - 64 GB - Verde) €129,99
# 5. Smartphone XIAOMI Redmi 9 (6.53'' - 3 GB - 32 GB - Verde) €129,99
# 5. Smartphone XIAOMI Redmi Note 9 (6.53'' -  4 GB - 128 GB - Cinzento) €180,50
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 64 GB - Cinzento) €215,00
# 5. Smartphone XIAOMI Redmi 9 (6.53'' - 3 GB - 32 GB - Cinzento) €126,99
# 5. Smartphone XIAOMI Poco X3 NFC (6 GB - 128 GB - Cinzento) €257,40
# 5. Smartphone XIAOMI Redmi Note 9S (6.67'' - 6 GB - 128 GB - Azul) €279,99
# 5. Smartphone XIAOMI Redmi Note 9S (6.67" - 6 GB - 128 GB - Cinzento) €202,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 64 GB - Verde) €289,99
# 5. Smartphone XIAOMI Redmi 9C NFC (6.53'' - 2 GB - 32 GB - Azul) €119,00
# 5. Smartphone XIAOMI Redmi Note 9S (6.67'' - 6 GB - 128 GB - Branco) €279,99
# 5. Smartphone XIAOMI Mi 10 Lite 5G (6.57'' - 6 GB - 128 GB - Cinzento) €289,00
# 5. Smartphone XIAOMI Redmi Note 8T (6.3'' - 4 GB - 64 GB - Azul) €185,39
# 5. Smartphone XIAOMI Mi 10T Pro 5G (6.67'' - 8 GB - 128 GB - Preto) €599,90
# 5. Smartphone XIAOMI Redmi Note 8 Pro (6.53'' - 6 GB - 128 GB - Verde) €204,99
# 5. Smartphone XIAOMI Redmi Note 9 (6.53'' - 4 GB - 128 GB - Branco) €269,99
# 5. Smartphone XIAOMI Redmi 8 (6.22'' - 4 GB - 64 GB - Azul) €145,89
# 5. Smartphone XIAOMI Poco X3 NFC (6 GB - 64 GB - Cinzento) €229,02
# 5. Consola Portátil Nintendo Switch V2 (32 GB - Azul  e Vermelho Néon) €279,99
# 5. Consola Nintendo Switch Lite + Animal Crossing (32 GB - Turquesa) €229,00
# 5. iPhone SE APPLE (4.7'' - 128 GB - Preto) €449,99
# 5. Coluna Bluetooth JBL Xtreme 2 GM (40W - Autonomia 15 horas) €149,99
# 5. SAMSUNG Galaxy Watch 46mm Cinza €199,99
# 5. Comando PS4 Dualshock Black v2 (Wireless) €39,99
# 5. Smartphone XIAOMI Redmi Note 9 Pro (6.67'' - 6 GB - 128 GB - Branco) €229,99
# 5. Máquina de Café KRUPS Nespresso Essenza XN1108P2 (19 bar - Preto) €22,00
# 5. TV LG 75UN85006 (LED - 75'' - 191 cm - 4K Ultra HD - Smart TV) €999,99
# 5. Monitor LG 29WL500-B (29'' - Full HD - LED IPS - FreeSync) €179,99
# 5. Tablet SAMSUNG Galaxy Tab S6 Lite (10.4'' - 64 GB - 4 GB RAM - Wi-Fi - Cinzento) €299,99
# 5. Desktop Gaming HP Pavilion TG01-1024np (Intel Core i5-10400F - NVIDIA GeForce GTX 1660 Super - RAM: 16 GB - 512 GB SSD PCIe) €749,99
# 5. Kit Máquina Fotográfica Reflex CANON EOS 2000D + 18-55 mm DC + Bolsa SB130 + 16 GB (24.1 MP - Sensor APS-C - ISO: 100 a 12800) €299,99
# 5. Purificador de Ar  AIRFREE P3000 ( 32 m2) €99,99
# 5. Consola PS4 Slim + FIFA 21 (500 GB) €299,99
# 5. Aspirador Vertical DYSON V8 Animal + (21.6 V - Autonomia: 40 min - 540 ml) €269,99
# 5. Máquina de Lavar Roupa SAMSUNG Addwash WW80T554DTW (8 kg - 1400 rpm - Branco) €379,99
# 5. Máquina de Lavar Loiça CANDY CDPN 2D360PW (13 Conjuntos - 60 cm - Branco) €279,99
# 5. Placa de Indução BECKEN BIH3300 (Elétrica - 59 cm - Preto) €199,99
# 5. Frigorífico Americano LG GSX961MCVZ Instaview (No Frost - 179 cm - 601 L - Preto) €1599,00
# 5. Cave de Vinho BECKEN BWC3989 (17 Garrafas - Inox) €149,99
# 5. Micro-ondas LG NeoChef MH6336GIB (23 L - Com Grill - Preto) €99,99
# 5. Máquina de Lavar Roupa  BEKO WTA 9712 XSWR (9 kg - 1400 rpm - Branco) €289,99
# 5. Máquina de Secar Roupa HOTPOINT NT M11 82SK EU (8kg - Bomba de Calor - Branco) €459,99
# 5. TV LG OLED55CX5 (OLED - 55'' - 140 cm - 4K Ultra HD - Smart TV) €1249,00
# 5. Robô de Cozinha MOULINEX ICompanion HF900110 (4.5 L - 1550 W - 5 acessórios) €399,99
# 5. Varinha BOSCH MSM67170 (750 W - 12 velocidades) €34,99
# 5. Auscultador Bluetooth PHILIPS TAPH805BK (Over Ear - Microfone - Noise Canceling) €89,99
# 5. Smartphone SAMSUNG Galaxy A20s (6.5'' - 3 GB - 32 GB - Preto) €129,99
# 5. Sistema Mesh TP-LINK Deco M4 2 Unid. (AC1200 - 300 + 867 Mbps) €69,99
# 5. Perfume CALVIN KLEIN Endless Euphoria Eau de Parfum (125 ml) €29,97
# 5. Trator a Pedal HOMCOM 341-018 (114 x 41 x 52 cm) €74,99

# %% [markdown]
# # El Corte Inglês Product Prices

# %%
def extract_prices_elcorteingles(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    price_container = soup.find("div", class_="product-price")
    if price_container:
        current_price_tag = price_container.find("span", class_="current")
        old_price_tag = price_container.find("span", class_="former stroked")
        
        current_price = current_price_tag.get_text(strip=True) if current_price_tag else None
        old_price = old_price_tag.get_text(strip=True) if old_price_tag else None
        
        if current_price:
            print('1.', old_price, current_price)
            return {'old_price': old_price, 'current_price': current_price}



    return None


def process_row_elcorteingles(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        if link == row['linkToArchive']:
            link = link.replace(f'/http://{site}/', f'mp_/http://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.elcorteingles.pt':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
            
            extracted_data = extract_prices_elcorteingles(text, site)
            
            if extracted_data:

                old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                price = [current, old] if old and current else [current]
                
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': price,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')        
result_list = process_row_elcorteingles(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_ELCORTEINGLES.csv', index=False)
# Out:
# 1. None 259,90€
# 1. None 259,90€
# 1. None 699,90€
# 1. 799,90€ 559,90€
# 1. 799,90€ 619,99€
# 1. 999,90€ 789,99€
# 1. None 799,90€
# 1. None 919,90€
# 1. None 869,90€
# 1. None 869,90€
# 1. None 1.029,90€
# 1. None 929,90€
# 1. 449€ 399€
# 1. 449€ 399€
# 1. None 1.029€
# 1. None 829€
# 1. None 829€
# 1. None 879€
# 1. None 1.179€
# 1. None 1.179€
# 1. None 1.359€
# 1. None 1.179€
# 1. None 1.179€
# 1. None 1.179€
# 1. None 1.179€
# 1. None 1.279€
# Error while fetching https://arquivo.pt/wayback/20190422182330mp_/https://www.elcorteingles.pt/tecnologia/A27722117-smartphone-apple-iphone-xr-64gb---black/?utm_source=kuantokusta&utm_medium=cpc&utm_campaign=catalogo
# 1. None 879€
# 1. None 939€
# 1. None 349,90€
# 1. None 349,90€
# 1. 69,99€ 49,99€
# 1. 69,99€ 44,99€
# 1. None 69,99€
# 1. 44,99€ 29,99€

# %%
df = pd.read_csv('data/resultados_black_friday_arquivo.csv')
result_list = process_row_elcorteingles(df)
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_ELCORTEINGLES_Black_Friday.csv', index=False)
# Out:
# 1. 22,99€ 17,24€
# 1. 22,99€ 17,24€
# 1. 69,99€ 49,99€
# 1. 69,99€ 49,99€
# 1. 299,99€ 199€
# 1. None 10€
# 1. 108,80€ 81,60€
# 1. 108,80€ 81,60€
# 1. None 69,99€
# 1. 44,99€ 29,99€
# 1. 39,99€ 9,99€
# 1. 39,99€ 9,99€
# 1. 108,80€ 81,60€
# 1. 108,80€ 81,60€

# %% [markdown]
# # Staples Product Prices

# %%
def extract_prices_staples(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    price_label = soup.find("div", id="PriceLabel")
    if price_label:
        current_price_tag = price_label.find("span", class_="priceupdate")
        current_price = current_price_tag.get_text(strip=True) if current_price_tag else None
        
        if current_price:
            print('1.', current_price)
            return {'current_price': current_price}


    return None


def process_row_staples(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        if link == row['linkToArchive']:
            link = link.replace(f'/http://{site}/', f'mp_/http://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.staples.pt':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
            
            extracted_data = extract_prices_staples(text, site)
            
            if extracted_data:

                old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                price = [current, old] if old and current else [current]
                
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': price,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')        
result_list = process_row_staples(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_STAPLES.csv', index=False)
# Out:
# 1. 649,00€
# 1. 649,00€
# 1. 633,33
# 1. 779,67
# 1. 820,33
# 1. 673,98
# 1. 16,25
# 1. 16,25

# %% [markdown]
# Nao encontrei produtos para a campanha black friday da staples, por isso nao extrai os preços dos produtos.

# %% [markdown]
# # PcDiga Product Prices

# %%
def extract_prices_pcdiga(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    product_cards = soup.find_all("div", class_="product_special_container_fixer")
    if product_cards:
        products = []
        for card in product_cards:
            # Extract product name
            name_tag = card.find("div", class_="product-card--title")
            name = name_tag.get_text(strip=True) if name_tag else None

            # Extract product price
            price_tag = card.find("div", class_="value--current-price").find("span", class_="price")
            price = price_tag.get_text(strip=True) if price_tag else None
            print('1.', name, price)
            if name and price:
                products.append({
                    'product_name': name,
                    'current_price': price
                })

        return products 
    
    price_label = soup.find("span", class_="new-price-label")
    if price_label:
        current_price = price_label.get_text(strip=True)
        
        if current_price:
            print('2.', current_price)
            return {'current_price': current_price}

    price_container = soup.find("div", class_="value--current-price")
    if price_container:
        span = price_container.find("span", class_="price")
        current_price = span.get_text(strip=True) if span else None
        print('3.', current_price)  
        return {'current_price': current_price}
    
    products = []
    product_items = soup.find_all("li", class_="item last")
    for item in product_items:
        name_tag = item.find("h2", class_="product-name")
        price_tag = item.find("span", class_="price")

        product_name = name_tag.get_text(strip=True) if name_tag else None
        current_price = price_tag.get_text(strip=True) if price_tag else None
        print('4.', product_name, current_price)
        if product_name and current_price:
            products.append({
                'product_name': product_name,
                'current_price': current_price
            })

    return products if products else None



def process_row_pcdiga(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.pcdiga.com':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
            
            extracted_data = extract_prices_pcdiga(text, site)
            
            if extracted_data:
                if isinstance(extracted_data, list):
                    for product in extracted_data:
                        old = product['old_price'] if 'old_price' in product else None
                        current = product['current_price'] if 'current_price' in product else None
                        price = [current, old] if old and current else [current]
                        titulo = product['product_name'] if 'product_name' in product else None
                        extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': titulo,
                            'extractedData': price,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
                else:
                    old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                    current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                    price = [current, old] if old and current else [current]
                    
                    extracted_data_list.append({
                        'site': site,
                        'date': date,
                        'title': title,
                        'extractedData': price,
                        'linkToArchive': link,
                        'linkToExtractedText': row['linkToExtractedText'],
                        'snippet': snippet
                    })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/smartphones_arquivo.csv')        
result_list = process_row_pcdiga(df)               
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_PcDiga.csv', index=False)
# Out:
# 2. 39,90€
# 2. 44,90€
# 2. 1 019,00€
# 2. 1 019,00€
# 3. 929,90€
# 3. 929,90€
# 2. 469,90€
# 2. 649,00€
# 2. 619,00€
# 2. 619,00€
# 2. 1 199,00€
# 2. 1 349,00€
# 2. 1 049,00€
# 2. 799,00€
# 2. 999,00€
# 2. 1 349,00€
# 2. 1 179,00€
# 2. 1 349,00€
# 2. 1 349,00€
# 2. 1 349,00€
# 2. 1 179,00€
# 2. 1 349,00€
# 2. 1 049,00€
# 2. 799,00€
# 2. 729,00€
# 2. 1 049,00€
# 3. 409,90€
# 3. 459,90€
# 4. Consola Microsoft Xbox One 500 GB (5C5-00013) 239,90 €
# 4. Microsoft Xbox One 1TB Rainbow Six Siege 269,90 €
# 4. Consola Microsoft Xbox One S 500GB + Battlefield 1 289,90 €
# 4. Microsoft Xbox One 500GB + Quantum Break 299,90 €
# 4. Consola Microsoft Xbox One S 500GB + Fifa 17 299,90 €
# 4. Microsoft Xbox One 1TB Tom Clancy's The Division 349,90 €
# 4. Consola Microsoft Xbox One 500GB+Kinect+Assassin's Creed 389,90 €
# 4. Consola Microsoft Xbox One 1TB Call of Duty: Advanced Warfare 489,90 €
# 4. Microsoft Xbox One 1TB Rainbow Six Siege 269,90 €
# 4. Microsoft Xbox One 500GB + Quantum Break 299,90 €
# 4. Microsoft Xbox One 1TB Tom Clancy's The Division 349,90 €
# 4. Consola Microsoft Xbox One 1TB Call of Duty: Advanced Warfare 489,90 €

# %%
df = pd.read_csv('data/resultados_black_friday_arquivo.csv')
result_list = process_row_pcdiga(df)
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_PcDiga_Black_Friday.csv', index=False)
# Out:
# 1. Smartphone Oppo A15 6.52" 3GB/32GB Dual SIM Mystery Blue 169,90€
# 1. Smartphone Oppo A15 6.52" 3GB/32GB Dual SIM Dynamic Black 169,90€
# 1. Smartphone OnePlus Nord N100 6.52" 4GB/64GB Dual SIM Midnight Frost 199,00€
# 1. Smartphone TCL 10 Plus 6.47" 6GB/256GB Dual SIM Azul 399,90€
# 1. Smartphone TCL 10 Plus 6.47" 6GB/256GB Dual SIM Cinzento 399,90€
# 1. Película de Protecção 3MK Antimicrobiana Silver Protection+ Xiaomi Redmi Note 9 11,90€
# 1. Smartphone Huawei Mate 40 Pro 6.76" 8GB/256GB Dual SIM Prateado 1249,00€
# 1. Smartphone Oppo A53 6.5" 4GB/64GB Dual SIM Mint Cream 189,00€
# 1. Smartphone Oppo A53 6.5" 4GB/64GB Dual SIM Electric Black 189,00€
# 1. Smartphone Oppo A53s 6.5" 4GB/128GB Dual SIM Fancy Blue 219,00€
# 1. Smartphone Oppo A53s 6.5" 4GB/128GB Dual SIM Electric Black 219,00€
# 1. Smartphone Oppo Reno 4 Z 5G 6.57" 8GB/128GB Dual SIM Dew White 399,00€
# 1. Smartphone Oppo Reno 4 Z 5G 6.57" 8GB/128GB Dual SIM Ink Black 399,00€
# 1. Smartphone Oppo Reno 4 5G 6.43" 8GB/128GB Dual SIM Space Black 599,00€
# 1. Smartphone Oppo Reno 4 5G 6.43" 8GB/128GB Dual SIM Galactic Blue 599,00€
# 1. Smartphone Oppo Reno 4 Pro 5G 6.55" 12GB/256GB Dual SIM Galactic Blue 799,00€
# 1. Smartphone Oppo Reno 4 Pro 5G 6.55" 12GB/256GB Dual SIM Space Black 799,00€
# 1. Smartphone Xiaomi Redmi Note 9 6.53" 3GB/64GB Dual SIM Preto 158,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Verde 259,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Dourado 259,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Preto 259,90€
# 1. Smartphone Motorola Moto E7 Plus 6.5" 4GB/64GB Dual SIM Azul 129,90€
# 1. Smartphone Motorola G9 Play 6.5" 4GB/64GB Dual SIM Azul 149,90€
# 1. Smartphone Blackview BV6300 Pro 5.7" 6GB/128GB Dual SIM Preto 239,90€
# 1. Smartphone Motorola Moto G9 Plus 6.81" 4GB/128GB Dual SIM Azul 219,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Rose Gold Beach 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Rose Gold Beach 329,00€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Pearl Gray 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Atlantic Blue 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Atlantic Blue 329,00€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Pearl Gray 329,00€
# 1. Smartphone Xiaomi Mi 10T 5G 6.67" 6GB/128GB Dual SIM Lunar Silver 439,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/256GB Dual SIM Lunar Silver 649,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/256GB Dual SIM Cosmic Black 649,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/128GB Dual SIM Lunar Silver 599,00€
# 1. Smartphone Xiaomi Mi 10T 5G 6.67" 6GB/128GB Dual SIM Cosmic Black 439,90€
# 1. Smartphone Oppo A15 6.52" 3GB/32GB Dual SIM Mystery Blue 169,90€
# 1. Smartphone Oppo A15 6.52" 3GB/32GB Dual SIM Dynamic Black 169,90€
# 1. Smartphone OnePlus Nord N100 6.52" 4GB/64GB Dual SIM Midnight Frost 199,00€
# 1. Smartphone TCL 10 Plus 6.47" 6GB/256GB Dual SIM Azul 399,90€
# 1. Smartphone TCL 10 Plus 6.47" 6GB/256GB Dual SIM Cinzento 399,90€
# 1. Película de Protecção 3MK Antimicrobiana Silver Protection+ Xiaomi Redmi Note 9 11,90€
# 1. Smartphone Huawei Mate 40 Pro 6.76" 8GB/256GB Dual SIM Prateado 1249,00€
# 1. Smartphone Oppo A53 6.5" 4GB/64GB Dual SIM Mint Cream 189,00€
# 1. Smartphone Oppo A53 6.5" 4GB/64GB Dual SIM Electric Black 189,00€
# 1. Smartphone Oppo A53s 6.5" 4GB/128GB Dual SIM Fancy Blue 219,00€
# 1. Smartphone Oppo A53s 6.5" 4GB/128GB Dual SIM Electric Black 219,00€
# 1. Smartphone Oppo Reno 4 Z 5G 6.57" 8GB/128GB Dual SIM Dew White 399,00€
# 1. Smartphone Oppo Reno 4 Z 5G 6.57" 8GB/128GB Dual SIM Ink Black 399,00€
# 1. Smartphone Oppo Reno 4 5G 6.43" 8GB/128GB Dual SIM Space Black 599,00€
# 1. Smartphone Oppo Reno 4 5G 6.43" 8GB/128GB Dual SIM Galactic Blue 599,00€
# 1. Smartphone Oppo Reno 4 Pro 5G 6.55" 12GB/256GB Dual SIM Galactic Blue 799,00€
# 1. Smartphone Oppo Reno 4 Pro 5G 6.55" 12GB/256GB Dual SIM Space Black 799,00€
# 1. Smartphone Xiaomi Redmi Note 9 6.53" 3GB/64GB Dual SIM Preto 158,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Verde 259,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Dourado 259,90€
# 1. Smartphone Huawei P Smart 2021 6.67" 4GB/128GB Dual SIM Preto 259,90€
# 1. Smartphone Motorola Moto E7 Plus 6.5" 4GB/64GB Dual SIM Azul 129,90€
# 1. Smartphone Motorola G9 Play 6.5" 4GB/64GB Dual SIM Azul 149,90€
# 1. Smartphone Blackview BV6300 Pro 5.7" 6GB/128GB Dual SIM Preto 239,90€
# 1. Smartphone Motorola Moto G9 Plus 6.81" 4GB/128GB Dual SIM Azul 219,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Rose Gold Beach 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Rose Gold Beach 329,00€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Pearl Gray 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/128GB Dual SIM Atlantic Blue 319,90€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Atlantic Blue 329,00€
# 1. Smartphone Xiaomi Mi 10T Lite 5G 6.67" 6GB/64GB Dual SIM Pearl Gray 329,00€
# 1. Smartphone Xiaomi Mi 10T 5G 6.67" 6GB/128GB Dual SIM Lunar Silver 439,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/256GB Dual SIM Lunar Silver 649,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/256GB Dual SIM Cosmic Black 649,00€
# 1. Smartphone Xiaomi Mi 10T Pro 5G 6.67" 8GB/128GB Dual SIM Lunar Silver 599,00€
# 1. Smartphone Xiaomi Mi 10T 5G 6.67" 6GB/128GB Dual SIM Cosmic Black 439,90€

# %% [markdown]
# # Radio Popular Product Prices

# %%
def extract_prices_radiopopular(text, site):
    soup = BeautifulSoup(text, 'html.parser')

    old_price_tag = soup.find("div", class_="old-price notranslate")
    old_price = old_price_tag.get_text(strip=True) if old_price_tag else None

    price_tag = soup.find("div", class_="price notranslate")

    if price_tag:
        current_price = price_tag.get_text(strip=True)
        print('1.', old_price, current_price)
        return {'old_price': old_price, 'current_price': current_price}


def process_row_radiopopular(df):
    extracted_data_list = []
    for index, row in df.iterrows():
        link = row['linkToArchive']
        site = row['site'] 
        link = link.replace(f'/https://{site}/', f'mp_/https://{site}/')
        tstamp = str(row['tstamp'])
        date = tstamp[:8]
        title = row['title']
        snippet = row['snippet']

        
        if site == 'www.radiopopular.pt':
            try:
                response = requests.get(link)
                response.raise_for_status()
                text = response.text
            except requests.RequestException:
                print(f"Error while fetching {link}")
                extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': title,
                            'extractedData': None,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
            
            extracted_data = extract_prices_radiopopular(text, site)
            
            if extracted_data:
                if isinstance(extracted_data, list):
                    for product in extracted_data:
                        old = product['old_price'] if 'old_price' in product else None
                        current = product['current_price'] if 'current_price' in product else None
                        price = [current, old] if old and current else [current]
                        titulo = product['product_name'] if 'product_name' in product else None
                        extracted_data_list.append({
                            'site': site,
                            'date': date,
                            'title': titulo,
                            'extractedData': price,
                            'linkToArchive': link,
                            'linkToExtractedText': row['linkToExtractedText'],
                            'snippet': snippet
                        })
                else:
                    old = extracted_data['old_price'] if 'old_price' in extracted_data else None
                    current = extracted_data['current_price'] if 'current_price' in extracted_data else None
                    price = [current, old] if old and current else [current]
                    
                    extracted_data_list.append({
                        'site': site,
                        'date': date,
                        'title': title,
                        'extractedData': price,
                        'linkToArchive': link,
                        'linkToExtractedText': row['linkToExtractedText'],
                        'snippet': snippet
                    })

            else:
                extracted_data_list.append({
                    'site': site,
                    'date': date,
                    'title': title,
                    'extractedData': None,
                    'linkToArchive': link,
                    'linkToExtractedText': row['linkToExtractedText'],
                    'snippet': snippet
                })
    
    return extracted_data_list

# %%
df = pd.read_csv('data/resultados_black_friday_arquivo.csv')
result_list = process_row_radiopopular(df)
df_result = pd.DataFrame(result_list)
df_result.columns = ['site', 'date', 'title', 'extractedData', 'linkToArchive', 'linkToExtractedText', 'snippet']
df_result.to_csv('data/products_extracted_prices_RadioPopular_Black_Friday.csv', index=False)
# Out:
# 1. 719,99 666,99
# 1. 1.129,00 846,75
# 1. 1.129,00 846,75
# 1. 99,00 22,00
